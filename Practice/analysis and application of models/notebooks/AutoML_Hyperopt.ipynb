# %% [markdown]
# # Hyperopt локально и распределенно

# %% [markdown]
# Установим необходимые пакеты и поищем Spark

# %%
#!pip install findspark

# %%
import findspark
findspark.init()

# %%
import pyspark

# %%
import numpy as np 
import pandas as pd 
from sklearn.ensemble import RandomForestClassifier 
from sklearn import metrics
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import StandardScaler 
from hyperopt import tpe, hp, fmin, STATUS_OK,Trials
from hyperopt.pyll.base import scope

import warnings
warnings.filterwarnings("ignore")

# %%
# !pip install hyperopt

# %% [markdown]
# Прочитаем данные

# %%
df = pd.read_csv('path/to/train.csv')

# %%
df
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# 0       0.6        188        2  ...         20       756  2549     9     7
# 1       0.7        136        3  ...        905      1988  2631    17     3
# 2       0.9        145        5  ...       1263      1716  2603    11     2
# 3       0.8        131        6  ...       1216      1786  2769    16     8
# 4       0.6        141        2  ...       1208      1212  1411     8     2
# ...     ...        ...      ...  ...        ...       ...   ...   ...   ...
# 1995    0.8        106        6  ...       1222      1890   668    13     4
# 1996    0.2        187        4  ...        915      1965  2032    11    10
# 1997    0.7        108        8  ...        868      1632  3057     9     1
# 1998    0.1        145        5  ...        336       670   869    18    10
# 1999    0.9        168        6  ...        483       754  3919    19     4
#
#       talk_time  three_g  touch_screen  wifi  price_range
# 0            19        0             0     1            1
# 1             7        1             1     0            2
# 2             9        1             1     0            2
# 3            11        1             0     0            2
# 4            15        1             1     0            1
# ...         ...      ...           ...   ...          ...
# 1995         19        1             1     0            0
# 1996         16        1             1     1            2
# 1997          5        1             1     0            3
# 1998         19        1             1     1            0
# 1999          2        1             1     1            3
#
# [2000 rows x 21 columns]

# %% [markdown]
# Разделим набор на тестовый и целевой

# %%
X = df.drop("price_range", axis=1).values 
y = df.price_range.values

# %%
y
# Out:
# array([1, 2, 2, ..., 3, 0, 3])

# %% [markdown]
# Стандартизуем данные

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# ## Локальное обучение с помощью HyperOpt

# %%
space = {
    "n_estimators": hp.choice("n_estimators", [100, 200, 300, 400,500,600]),
    "max_depth": hp.quniform("max_depth", 1, 15, 1),
    "criterion": hp.choice("criterion", ["gini", "entropy"]),
}

# %% [markdown]
# Настроим гиперпараметры

# %%
def hyperparameter_tuning(params):
    if 'max_depth' in params.keys():
        params['max_depth'] = int(params['max_depth'])
    clf = RandomForestClassifier(**params, n_jobs=-1)
    acc = cross_val_score(clf, X_scaled, y, scoring="accuracy").mean()
    return {"loss": -acc, "status": STATUS_OK}

# %% [markdown]
# ### Сначала запустить ячейку - потом рассказывать

# %% [markdown]
# Инициализация объекта испытания

# %%
trials = Trials()

best = fmin(
    fn=hyperparameter_tuning,
    space = space, 
    algo=tpe.suggest, 
    max_evals=100, 
    trials=trials
)
# Out:
# 100%|██████████| 100/100 [05:38<00:00,  3.38s/trial, best loss: -0.8895]

# %% [markdown]
# Лучшие параметры модели

# %%
best
# Out:
# {'criterion': 1, 'max_depth': 14.0, 'n_estimators': 2}

# %% [markdown]
# Метаданные объекта

# %%
trials.trials
# Out:
# [{'state': 2,
#   'tid': 0,
#   'spec': None,
#   'result': {'loss': -0.6915, 'status': 'ok'},
#   'misc': {'tid': 0,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [0], 'max_depth': [0], 'n_estimators': [0]},
#    'vals': {'criterion': [1], 'max_depth': [2.0], 'n_estimators': [4]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 7, 18, 16, 1, 28, 492000),
#   'refresh_time': datetime.datetime(2022, 7, 18, 16, 1, 32, 101000)},
#  {'state': 2,
#   'tid': 1,
#   'spec': None,
#   'result': {'loss': -0.869, 'status': 'ok'},
#   'misc': {'tid': 1,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [1], 'max_depth': [1], 'n_estimators': [1]},
#    'vals': {'criterion': [0], 'max_depth': [8.0], 'n_estimators': [5]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 7, 18, 16, 1, 32, 104000),
#   'refresh_time': datetime.datetime(2022, 7, 18, 16, 1, 36, 407000)},
#  {'state': 2,
#   'tid': 2,
#   'spec': None,
#   'result': {'loss': -0.8859999999999999, 'status': 'ok'},
#   'misc': {'tid': 2,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [2], 'max_depth': [2], 'n_estimators': [2]},
#    'vals': {'criterion': [0], 'max_depth': [13.0], 'n_estimators': [1]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 7, 18, 16, 1, 36, 409000),
#   'refresh_time': datetime.datetime(2022, 7, 18, 16, 1, 38, 94000)},
#  {'state': 2,
#   'tid': 3,
#   'spec': None,
#   'result': {'loss': -0.8720000000000001, 'status': 'ok'},
#   'misc': {'tid': 3,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [3], 'max_depth': [3], 'n_estimators': [3]},
#    'vals': {'criterion': [1], 'max_depth': [9.0], 'n_estimators': [0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 7, 18, 16, 1, 38, 97000),
#   'refresh_time': datetime.datetime(2022, 7, 18, 16, 1, 39, 43000)},
#  {'state': 2,
#   'tid': 4,
#   'spec': None,
#   'result': {'loss': -0.8710000000000001, 'status': 'ok'},
#   'misc': {'tid': 4,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [4], 'max_depth': [4], 'n_estimators': [4]},
#    'vals': {'criterion': [1], 'max_depth': [8.0], 'n_estimators': [0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 7, 18, 16, 1, 39, 46000),
#   'refresh_time': datetime.datetime(2022, 7, 18, 16, 1, 39, 989000)},
#  {'state': 2,
#   'tid': 5,
#   'spec': None,
#   'result': {'loss': -0.881, 'status': 'ok'},
#   'misc': {'tid': 5,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [5], 'max_depth': [5], 'n_estimators': [5]},
#    'vals': {'criterion': [1], 'max_depth': [12.0], 'n_estimators': [0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 7, 18, 16, 1, 39, 991000),
#   'refresh_time': datetime.datetime(2022, 7, 18, 16, 1, 40, 992000)},
#  {'state': 2,
#   'tid': 6,
#   'spec': None,
#   'result': {'loss': -0.865, 'status': 'ok'},
#   'misc': {'tid': 6,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [6], 'max_depth': [6], 'n_estimators': [6]},
#    'vals': {'criterion': [0], 'max_depth': [7.0], 'n_estimators': [0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 7, 18, 16, 1, 40, 995000),
#   'refresh_time': datetime.datetime(2022, 7, 18, 16, 1, 41, 777000)},
#  {'state': 2,
#   'tid': 7,
#   'spec': None,
#   'result': {'loss': -0.875, 'status': 'ok'},
#   'misc': {'tid': 7,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [7], 'max_depth': [7], 'n_estimators': [7]},
#    'vals': {'criterion': [0], 'max_depth': [12.0], 'n_estimators': [3]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 7, 18, 16, 1, 41, 780000),
#   'refresh_time': datetime.datetime(2022, 7, 18, 16, 1, 44, 961000)},
#  {'state': 2,
#   'tid': 8,
#   'spec': None,
#   'result': {'loss': -0.8870000000000001, 'status': 'ok'},
#   'misc': {'tid': 8,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [8], 'max_depth': [8], 'n_estimators': [8]},
#    'vals': {'criterion': [1], 'max_depth': [12.0], 'n_estimators': [4]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 7, 18, 16, 1, 44, 963000),
#   'refresh_time': datetime.datetime(2022, 7, 18, 16, 1, 49, 469000)},
#  {'state': 2,
#   'tid': 9,
#   'spec': None,
#   'result': {'loss': -0.874, 'status': 'ok'},
#   'misc': {'tid': 9,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [9], 'max_depth': [9], 'n_estimators': [9]},
#    'vals': {'criterion': [0], 'max_depth': [10.0], 'n_estimators': [1]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 7, 18, 16, 1, 49, 473000),
#   'refresh_time': datetime.datetime(2022, 7, 18, 16, 1, 51, 97000)},
#  {'state': 2,
#   'tid': 10,
#   'spec': None,
#   'result': {'loss': -0.8835000000000001, 'status': 'ok'},
#   'misc': {'tid': 10,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [10], 'max_depth': [10], 'n_estimators': [10]},
#    'vals': {'criterion': [0], 'max_depth': [14.0], 'n_estimators': [1]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 7, 18, 16, 1, 51, 100000),
#   'refresh_time': datetime.datetime(2022, 7, 18, 16, 1, 52, 769000)},
#  {'state': 2,
#   'tid': 11,
#   'spec': None,
#   'result': {'loss': -0.8720000000000001, 'status': 'ok'},
#   'misc': {'tid': 11,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [11], 'max_depth': [11], 'n_estimators': [11]},
#    'vals': {'criterion': [1], 'max_depth': [8.0], 'n_estimators': [0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 7, 18, 16, 1, 52, 772000),
#   'refresh_time': datetime.datetime(2022, 7, 18, 16, 1, 53, 665000)},
#  {'state': 2,
#   'tid': 12,
#   'spec': None,
#   'result': {'loss': -0.8265, 'status': 'ok'},
#   'misc': {'tid': 12,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [12], 'max_depth': [12], 'n_estimators': [12]},
#    'vals': {'criterion': [1], 'max_depth': [4.0], 'n_estimators': [4]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 7, 18, 16, 1, 53, 668000),
#   'refresh_time': datetime.datetime(2022, 7, 18, 16, 1, 56, 846000)},
#  {'state': 2,
#   'tid': 13,
#   'spec': None,
#   'result': {'loss': -0.8795, 'status': 'ok'},
#   'misc': {'tid': 13,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [13], 'max_depth': [13], 'n_estimators': [13]},
#    'vals': {'criterion': [1], 'max_depth': [9.0], 'n_estimators': [1]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 7, 18, 16, 1, 56, 849000),
#   'refresh_time': datetime.datetime(2022, 7, 18, 16, 1, 58, 602000)},
#  {'state': 2,
#   'tid': 14,
#   'spec': None,
#   'result': {'loss': -0.8845000000000001, 'status': 'ok'},
#   'misc': {'tid': 14,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [14], 'max_depth': [14], 'n_estimators': [14]},
#    'vals': {'criterion': [1], 'max_depth': [14.0], 'n_estimators': [4]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 7, 18, 16, 1, 58, 605000),
#   'refresh_time': datetime.datetime(2022, 7, 18, 16, 2, 3, 263000)},
#  {'state': 2,
#   'tid': 15,
#   'spec': None,
#   'result': {'loss': -0.8355, 'status': 'ok'},
#   'misc': {'tid': 15,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [15], 'max_depth': [15], 'n_estimators': [15]},
#    'vals': {'criterion': [0], 'max_depth': [5.0], 'n_estimators': [2]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 7, 18, 16, 2, 3, 266000),
#   'refresh_time': datetime.datetime(2022, 7, 18, 16, 2, 5, 223000)},
#  {'state': 2,
#   'tid': 16,
#   'spec': None,
#   'result': {'loss': -0.8815, 'status': 'ok'},
#   'misc': {'tid': 16,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [16], 'max_depth': [16], 'n_estimators': [16]},
#    'vals': {'criterion': [0], 'max_depth': [12.0], 'n_estimators': [3]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 7, 18, 16, 2, 5, 227000),
#   'refresh_time': datetime.datetime(2022, 7, 18, 16, 2, 8, 409000)},
#  {'state': 2,
#   'tid': 17,
#   'spec': None,
#   'result': {'loss': -0.85, 'status': 'ok'},
#   'misc': {'tid': 17,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [17], 'max_depth': [17], 'n_estimators': [17]},
#    'vals': {'criterion': [0], 'max_depth': [6.0], 'n_estimators': [4]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 7, 18, 16, 2, 8, 412000),
#   'refresh_time': datetime.datetime(2022, 7, 18, 16, 2, 11, 716000)},
#  {'state': 2,
#   'tid': 18,
#   'spec': None,
#   'result': {'loss': -0.8865000000000001, 'status': 'ok'},
#   'misc': {'tid': 18,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [18], 'max_depth': [18], 'n_estimators': [18]},
#    'vals': {'criterion': [1], 'max_depth': [12.0], 'n_estimators': [1]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 7, 18, 16, 2, 11, 719000),
#   'refresh_time': datetime.datetime(2022, 7, 18, 16, 2, 13, 582000)},
#  {'state': 2,
#   'tid': 19,
#   'spec': None,
#   'result': {'loss': -0.8805, 'status': 'ok'},
#   'misc': {'tid': 19,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [19], 'max_depth': [19], 'n_estimators': [19]},
#    'vals': {'criterion': [1], 'max_depth': [11.0], 'n_estimators': [4]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 7, 18, 16, 2, 13, 586000),
#   'refresh_time': datetime.datetime(2022, 7, 18, 16, 2, 18, 83000)},
#  {'state': 2,
#   'tid': 20,
#   'spec': None,
#   'result': {'loss': -0.885, 'status': 'ok'},
#   'misc': {'tid': 20,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [20], 'max_depth': [20], 'n_estimators': [20]},
#    'vals': {'criterion': [1], 'max_depth': [15.0], 'n_estimators': [5]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 7, 18, 16, 2, 18, 90000),
#   'refresh_time': datetime.datetime(2022, 7, 18, 16, 2, 23, 610000)},
#  {'state': 2,
#   'tid': 21,
#   'spec': None,
#   'result': {'loss': -0.8845000000000001, 'status': 'ok'},
#   'misc': {'tid': 21,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [21], 'max_depth': [21], 'n_estimators': [21]},
#    'vals': {'criterion': [1], 'max_depth': [15.0], 'n_estimators': [2]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 7, 18, 16, 2, 23, 617000),
#   'refresh_time': datetime.datetime(2022, 7, 18, 16, 2, 26, 569000)},
#  {'state': 2,
#   'tid': 22,
#   'spec': None,
#   'result': {'loss': -0.881, 'status': 'ok'},
#   'misc': {'tid': 22,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [22], 'max_depth': [22], 'n_estimators': [22]},
#    'vals': {'criterion': [1], 'max_depth': [10.0], 'n_estimators': [1]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 7, 18, 16, 2, 26, 577000),
#   'refresh_time': datetime.datetime(2022, 7, 18, 16, 2, 28, 408000)},
#  {'state': 2,
#   'tid': 23,
#   'spec': None,
#   'result': {'loss': -0.8865000000000001, 'status': 'ok'},
#   'misc': {'tid': 23,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [23], 'max_depth': [23], 'n_estimators': [23]},
#    'vals': {'criterion': [1], 'max_depth': [13.0], 'n_estimators': [5]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 7, 18, 16, 2, 28, 415000),
#   'refresh_time': datetime.datetime(2022, 7, 18, 16, 2, 34, 51000)},
#  {'state': 2,
#   'tid': 24,
#   'spec': None,
#   'result': {'loss': -0.884, 'status': 'ok'},
#   'misc': {'tid': 24,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [24], 'max_depth': [24], 'n_estimators': [24]},
#    'vals': {'criterion': [1], 'max_depth': [14.0], 'n_estimators': [5]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 7, 18, 16, 2, 34, 59000),
#   'refresh_time': datetime.datetime(2022, 7, 18, 16, 2, 39, 634000)},
#  {'state': 2,
#   'tid': 25,
#   'spec': None,
#   'result': {'loss': -0.8850000000000001, 'status': 'ok'},
#   'misc': {'tid': 25,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [25], 'max_depth': [25], 'n_estimators': [25]},
#    'vals': {'criterion': [1], 'max_depth': [11.0], 'n_estimators': [4]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 7, 18, 16, 2, 39, 640000),
#   'refresh_time': datetime.datetime(2022, 7, 18, 16, 2, 44, 115000)},
#  {'state': 2,
#   'tid': 26,
#   'spec': None,
#   'result': {'loss': -0.8859999999999999, 'status': 'ok'},
#   'misc': {'tid': 26,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [26], 'max_depth': [26], 'n_estimators': [26]},
#    'vals': {'criterion': [1], 'max_depth': [13.0], 'n_estimators': [5]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 7, 18, 16, 2, 44, 123000),
#   'refresh_time': datetime.datetime(2022, 7, 18, 16, 2, 49, 568000)},
#  {'state': 2,
#   'tid': 27,
#   'spec': None,
#   'result': {'loss': -0.8815, 'status': 'ok'},
#   'misc': {'tid': 27,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [27], 'max_depth': [27], 'n_estimators': [27]},
#    'vals': {'criterion': [1], 'max_depth': [10.0], 'n_estimators': [5]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 7, 18, 16, 2, 49, 575000),
#   'refresh_time': datetime.datetime(2022, 7, 18, 16, 2, 54, 725000)},
#  {'state': 2,
#   'tid': 28,
#   'spec': None,
#   'result': {'loss': -0.6945, 'status': 'ok'},
#   'misc': {'tid': 28,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [28], 'max_depth': [28], 'n_estimators': [28]},
#    'vals': {'criterion': [1], 'max_depth': [2.0], 'n_estimators': [3]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 7, 18, 16, 2, 54, 734000),
#   'refresh_time': datetime.datetime(2022, 7, 18, 16, 2, 56, 967000)},
#  {'state': 2,
#   'tid': 29,
#   'spec': None,
#   'result': {'loss': -0.8835000000000001, 'status': 'ok'},
#   'misc': {'tid': 29,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [29], 'max_depth': [29], 'n_estimators': [29]},
#    'vals': {'criterion': [1], 'max_depth': [13.0], 'n_estimators': [2]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 7, 18, 16, 2, 56, 977000),
#   'refresh_time': datetime.datetime(2022, 7, 18, 16, 2, 59, 802000)},
#  {'state': 2,
#   'tid': 30,
#   'spec': None,
#   'result': {'loss': -0.557, 'status': 'ok'},
#   'misc': {'tid': 30,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [30], 'max_depth': [30], 'n_estimators': [30]},
#    'vals': {'criterion': [1], 'max_depth': [1.0], 'n_estimators': [5]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 7, 18, 16, 2, 59, 808000),
#   'refresh_time': datetime.datetime(2022, 7, 18, 16, 3, 2, 943000)},
#  {'state': 2,
#   'tid': 31,
#   'spec': None,
#   'result': {'loss': -0.8880000000000001, 'status': 'ok'},
#   'misc': {'tid': 31,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [31], 'max_depth': [31], 'n_estimators': [31]},
#    'vals': {'criterion': [1], 'max_depth': [15.0], 'n_estimators': [4]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 7, 18, 16, 3, 2, 949000),
#   'refresh_time': datetime.datetime(2022, 7, 18, 16, 3, 7, 548000)},
#  {'state': 2,
#   'tid': 32,
#   'spec': None,
#   'result': {'loss': -0.8859999999999999, 'status': 'ok'},
#   'misc': {'tid': 32,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [32], 'max_depth': [32], 'n_estimators': [32]},
#    'vals': {'criterion': [1], 'max_depth': [15.0], 'n_estimators': [4]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 7, 18, 16, 3, 7, 555000),
#   'refresh_time': datetime.datetime(2022, 7, 18, 16, 3, 12, 211000)},
#  {'state': 2,
#   'tid': 33,
#   'spec': None,
#   'result': {'loss': -0.8815, 'status': 'ok'},
#   'misc': {'tid': 33,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [33], 'max_depth': [33], 'n_estimators': [33]},
#    'vals': {'criterion': [1], 'max_depth': [14.0], 'n_estimators': [4]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 7, 18, 16, 3, 12, 219000),
#   'refresh_time': datetime.datetime(2022, 7, 18, 16, 3, 16, 931000)},
#  {'state': 2,
#   'tid': 34,
#   'spec': None,
#   'result': {'loss': -0.8805, 'status': 'ok'},
#   'misc': {'tid': 34,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [34], 'max_depth': [34], 'n_estimators': [34]},
#    'vals': {'criterion': [1], 'max_depth': [11.0], 'n_estimators': [4]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 7, 18, 16, 3, 16, 940000),
#   'refresh_time': datetime.datetime(2022, 7, 18, 16, 3, 21, 460000)},
#  {'state': 2,
#   'tid': 35,
#   'spec': None,
#   'result': {'loss': -0.867, 'status': 'ok'},
#   'misc': {'tid': 35,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [35], 'max_depth': [35], 'n_estimators': [35]},
#    'vals': {'criterion': [1], 'max_depth': [7.0], 'n_estimators': [4]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 7, 18, 16, 3, 21, 470000),
#   'refresh_time': datetime.datetime(2022, 7, 18, 16, 3, 25, 293000)},
#  {'state': 2,
#   'tid': 36,
#   'spec': None,
#   'result': {'loss': -0.8855000000000001, 'status': 'ok'},
#   'misc': {'tid': 36,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [36], 'max_depth': [36], 'n_estimators': [36]},
#    'vals': {'criterion': [1], 'max_depth': [13.0], 'n_estimators': [4]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 7, 18, 16, 3, 25, 300000),
#   'refresh_time': datetime.datetime(2022, 7, 18, 16, 3, 29, 857000)},
#  {'state': 2,
#   'tid': 37,
#   'spec': None,
#   'result': {'loss': -0.8745, 'status': 'ok'},
#   'misc': {'tid': 37,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [37], 'max_depth': [37], 'n_estimators': [37]},
#    'vals': {'criterion': [0], 'max_depth': [9.0], 'n_estimators': [4]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 7, 18, 16, 3, 29, 865000),
#   'refresh_time': datetime.datetime(2022, 7, 18, 16, 3, 33, 624000)},
#  {'state': 2,
#   'tid': 38,
#   'spec': None,
#   'result': {'loss': -0.7745, 'status': 'ok'},
#   'misc': {'tid': 38,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [38], 'max_depth': [38], 'n_estimators': [38]},
#    'vals': {'criterion': [1], 'max_depth': [3.0], 'n_estimators': [3]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 7, 18, 16, 3, 33, 631000),
#   'refresh_time': datetime.datetime(2022, 7, 18, 16, 3, 36, 11000)},
#  {'state': 2,
#   'tid': 39,
#   'spec': None,
#   'result': {'loss': -0.8779999999999999, 'status': 'ok'},
#   'misc': {'tid': 39,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [39], 'max_depth': [39], 'n_estimators': [39]},
#    'vals': {'criterion': [0], 'max_depth': [15.0], 'n_estimators': [0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 7, 18, 16, 3, 36, 20000),
#   'refresh_time': datetime.datetime(2022, 7, 18, 16, 3, 36, 917000)},
#  {'state': 2,
#   'tid': 40,
#   'spec': None,
#   'result': {'loss': -0.8720000000000001, 'status': 'ok'},
#   'misc': {'tid': 40,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [40], 'max_depth': [40], 'n_estimators': [40]},
#    'vals': {'criterion': [1], 'max_depth': [7.0], 'n_estimators': [4]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 7, 18, 16, 3, 36, 925000),
#   'refresh_time': datetime.datetime(2022, 7, 18, 16, 3, 40, 903000)},
#  {'state': 2,
#   'tid': 41,
#   'spec': None,
#   'result': {'loss': -0.8800000000000001, 'status': 'ok'},
#   'misc': {'tid': 41,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [41], 'max_depth': [41], 'n_estimators': [41]},
#    'vals': {'criterion': [1], 'max_depth': [9.0], 'n_estimators': [2]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 7, 18, 16, 3, 40, 911000),
#   'refresh_time': datetime.datetime(2022, 7, 18, 16, 3, 43, 600000)},
#  {'state': 2,
#   'tid': 42,
#   'spec': None,
#   'result': {'loss': -0.8795, 'status': 'ok'},
#   'misc': {'tid': 42,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [42], 'max_depth': [42], 'n_estimators': [42]},
#    'vals': {'criterion': [0], 'max_depth': [11.0], 'n_estimators': [0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 7, 18, 16, 3, 43, 609000),
#   'refresh_time': datetime.datetime(2022, 7, 18, 16, 3, 44, 512000)},
#  {'state': 2,
#   'tid': 43,
#   'spec': None,
#   'result': {'loss': -0.8859999999999999, 'status': 'ok'},
#   'misc': {'tid': 43,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [43], 'max_depth': [43], 'n_estimators': [43]},
#    'vals': {'criterion': [1], 'max_depth': [14.0], 'n_estimators': [4]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 7, 18, 16, 3, 44, 522000),
#   'refresh_time': datetime.datetime(2022, 7, 18, 16, 3, 49, 127000)},
#  {'state': 2,
#   'tid': 44,
#   'spec': None,
#   'result': {'loss': -0.8835000000000001, 'status': 'ok'},
#   'misc': {'tid': 44,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [44], 'max_depth': [44], 'n_estimators': [44]},
#    'vals': {'criterion': [1], 'max_depth': [12.0], 'n_estimators': [3]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 7, 18, 16, 3, 49, 136000),
#   'refresh_time': datetime.datetime(2022, 7, 18, 16, 3, 52, 759000)},
#  {'state': 2,
#   'tid': 45,
#   'spec': None,
#   'result': {'loss': -0.8634999999999999, 'status': 'ok'},
#   'misc': {'tid': 45,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [45], 'max_depth': [45], 'n_estimators': [45]},
#    'vals': {'criterion': [0], 'max_depth': [8.0], 'n_estimators': [4]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 7, 18, 16, 3, 52, 767000),
#   'refresh_time': datetime.datetime(2022, 7, 18, 16, 3, 56, 300000)},
#  {'state': 2,
#   'tid': 46,
#   'spec': None,
#   'result': {'loss': -0.881, 'status': 'ok'},
#   'misc': {'tid': 46,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [46], 'max_depth': [46], 'n_estimators': [46]},
#    'vals': {'criterion': [1], 'max_depth': [10.0], 'n_estimators': [0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 7, 18, 16, 3, 56, 308000),
#   'refresh_time': datetime.datetime(2022, 7, 18, 16, 3, 57, 272000)},
#  {'state': 2,
#   'tid': 47,
#   'spec': None,
#   'result': {'loss': -0.844, 'status': 'ok'},
#   'misc': {'tid': 47,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [47], 'max_depth': [47], 'n_estimators': [47]},
#    'vals': {'criterion': [0], 'max_depth': [6.0], 'n_estimators': [1]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 7, 18, 16, 3, 57, 281000),
#   'refresh_time': datetime.datetime(2022, 7, 18, 16, 3, 58, 651000)},
#  {'state': 2,
#   'tid': 48,
#   'spec': None,
#   'result': {'loss': -0.8869999999999999, 'status': 'ok'},
#   'misc': {'tid': 48,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [48], 'max_depth': [48], 'n_estimators': [48]},
#    'vals': {'criterion': [1], 'max_depth': [12.0], 'n_estimators': [4]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 7, 18, 16, 3, 58, 659000),
#   'refresh_time': datetime.datetime(2022, 7, 18, 16, 4, 3, 237000)},
#  {'state': 2,
#   'tid': 49,
#   'spec': None,
#   'result': {'loss': -0.889, 'status': 'ok'},
#   'misc': {'tid': 49,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [49], 'max_depth': [49], 'n_estimators': [49]},
#    'vals': {'criterion': [1], 'max_depth': [14.0], 'n_estimators': [2]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 7, 18, 16, 4, 3, 246000),
#   'refresh_time': datetime.datetime(2022, 7, 18, 16, 4, 6, 92000)},
#  {'state': 2,
#   'tid': 50,
#   'spec': None,
#   'result': {'loss': -0.884, 'status': 'ok'},
#   'misc': {'tid': 50,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [50], 'max_depth': [50], 'n_estimators': [50]},
#    'vals': {'criterion': [1], 'max_depth': [15.0], 'n_estimators': [2]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 7, 18, 16, 4, 6, 101000),
#   'refresh_time': datetime.datetime(2022, 7, 18, 16, 4, 8, 980000)},
#  {'state': 2,
#   'tid': 51,
#   'spec': None,
#   'result': {'loss': -0.8790000000000001, 'status': 'ok'},
#   'misc': {'tid': 51,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [51], 'max_depth': [51], 'n_estimators': [51]},
#    'vals': {'criterion': [0], 'max_depth': [14.0], 'n_estimators': [2]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 7, 18, 16, 4, 8, 990000),
#   'refresh_time': datetime.datetime(2022, 7, 18, 16, 4, 11, 593000)},
#  {'state': 2,
#   'tid': 52,
#   'spec': None,
#   'result': {'loss': -0.845, 'status': 'ok'},
#   'misc': {'tid': 52,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [52], 'max_depth': [52], 'n_estimators': [52]},
#    'vals': {'criterion': [1], 'max_depth': [5.0], 'n_estimators': [2]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 7, 18, 16, 4, 11, 604000),
#   'refresh_time': datetime.datetime(2022, 7, 18, 16, 4, 13, 763000)},
#  {'state': 2,
#   'tid': 53,
#   'spec': None,
#   'result': {'loss': -0.891, 'status': 'ok'},
#   'misc': {'tid': 53,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [53], 'max_depth': [53], 'n_estimators': [53]},
#    'vals': {'criterion': [1], 'max_depth': [13.0], 'n_estimators': [2]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 7, 18, 16, 4, 13, 772000),
#   'refresh_time': datetime.datetime(2022, 7, 18, 16, 4, 16, 708000)},
#  {'state': 2,
#   'tid': 54,
#   'spec': None,
#   'result': {'loss': -0.8800000000000001, 'status': 'ok'},
#   'misc': {'tid': 54,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [54], 'max_depth': [54], 'n_estimators': [54]},
#    'vals': {'criterion': [1], 'max_depth': [11.0], 'n_estimators': [2]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 7, 18, 16, 4, 16, 716000),
#   'refresh_time': datetime.datetime(2022, 7, 18, 16, 4, 19, 579000)},
#  {'state': 2,
#   'tid': 55,
#   'spec': None,
#   'result': {'loss': -0.881, 'status': 'ok'},
#   'misc': {'tid': 55,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [55], 'max_depth': [55], 'n_estimators': [55]},
#    'vals': {'criterion': [0], 'max_depth': [13.0], 'n_estimators': [2]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 7, 18, 16, 4, 19, 589000),
#   'refresh_time': datetime.datetime(2022, 7, 18, 16, 4, 22, 152000)},
#  {'state': 2,
#   'tid': 56,
#   'spec': None,
#   'result': {'loss': -0.8785000000000001, 'status': 'ok'},
#   'misc': {'tid': 56,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [56], 'max_depth': [56], 'n_estimators': [56]},
#    'vals': {'criterion': [1], 'max_depth': [9.0], 'n_estimators': [2]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 7, 18, 16, 4, 22, 161000),
#   'refresh_time': datetime.datetime(2022, 7, 18, 16, 4, 24, 880000)},
#  {'state': 2,
#   'tid': 57,
#   'spec': None,
#   'result': {'loss': -0.8575000000000002, 'status': 'ok'},
#   'misc': {'tid': 57,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [57], 'max_depth': [57], 'n_estimators': [57]},
#    'vals': {'criterion': [1], 'max_depth': [6.0], 'n_estimators': [2]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 7, 18, 16, 4, 24, 888000),
#   'refresh_time': datetime.datetime(2022, 7, 18, 16, 4, 27, 188000)},
#  {'state': 2,
#   'tid': 58,
#   'spec': None,
#   'result': {'loss': -0.8895, 'status': 'ok'},
#   'misc': {'tid': 58,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [58], 'max_depth': [58], 'n_estimators': [58]},
#    'vals': {'criterion': [1], 'max_depth': [12.0], 'n_estimators': [2]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 7, 18, 16, 4, 27, 198000),
#   'refresh_time': datetime.datetime(2022, 7, 18, 16, 4, 30, 44000)},
#  {'state': 2,
#   'tid': 59,
#   'spec': None,
#   'result': {'loss': -0.874, 'status': 'ok'},
#   'misc': {'tid': 59,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [59], 'max_depth': [59], 'n_estimators': [59]},
#    'vals': {'criterion': [0], 'max_depth': [10.0], 'n_estimators': [2]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 7, 18, 16, 4, 30, 54000),
#   'refresh_time': datetime.datetime(2022, 7, 18, 16, 4, 32, 511000)},
#  {'state': 2,
#   'tid': 60,
#   'spec': None,
#   'result': {'loss': -0.8720000000000001, 'status': 'ok'},
#   'misc': {'tid': 60,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [60], 'max_depth': [60], 'n_estimators': [60]},
#    'vals': {'criterion': [1], 'max_depth': [8.0], 'n_estimators': [2]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 7, 18, 16, 4, 32, 519000),
#   'refresh_time': datetime.datetime(2022, 7, 18, 16, 4, 35, 95000)},
#  {'state': 2,
#   'tid': 61,
#   'spec': None,
#   'result': {'loss': -0.883, 'status': 'ok'},
#   'misc': {'tid': 61,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [61], 'max_depth': [61], 'n_estimators': [61]},
#    'vals': {'criterion': [1], 'max_depth': [12.0], 'n_estimators': [1]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 7, 18, 16, 4, 35, 104000),
#   'refresh_time': datetime.datetime(2022, 7, 18, 16, 4, 36, 963000)},
#  {'state': 2,
#   'tid': 62,
#   'spec': None,
#   'result': {'loss': -0.884, 'status': 'ok'},
#   'misc': {'tid': 62,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [62], 'max_depth': [62], 'n_estimators': [62]},
#    'vals': {'criterion': [1], 'max_depth': [11.0], 'n_estimators': [3]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 7, 18, 16, 4, 36, 972000),
#   'refresh_time': datetime.datetime(2022, 7, 18, 16, 4, 40, 624000)},
#  {'state': 2,
#   'tid': 63,
#   'spec': None,
#   'result': {'loss': -0.8690000000000001, 'status': 'ok'},
#   'misc': {'tid': 63,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [63], 'max_depth': [63], 'n_estimators': [63]},
#    'vals': {'criterion': [1], 'max_depth': [7.0], 'n_estimators': [2]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 7, 18, 16, 4, 40, 632000),
#   'refresh_time': datetime.datetime(2022, 7, 18, 16, 4, 43, 3000)},
#  {'state': 2,
#   'tid': 64,
#   'spec': None,
#   'result': {'loss': -0.8780000000000001, 'status': 'ok'},
#   'misc': {'tid': 64,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [64], 'max_depth': [64], 'n_estimators': [64]},
#    'vals': {'criterion': [0], 'max_depth': [10.0], 'n_estimators': [0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 7, 18, 16, 4, 43, 12000),
#   'refresh_time': datetime.datetime(2022, 7, 18, 16, 4, 43, 863000)},
#  {'state': 2,
#   'tid': 65,
#   'spec': None,
#   'result': {'loss': -0.885, 'status': 'ok'},
#   'misc': {'tid': 65,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [65], 'max_depth': [65], 'n_estimators': [65]},
#    'vals': {'criterion': [1], 'max_depth': [14.0], 'n_estimators': [2]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 7, 18, 16, 4, 43, 872000),
#   'refresh_time': datetime.datetime(2022, 7, 18, 16, 4, 46, 757000)},
#  {'state': 2,
#   'tid': 66,
#   'spec': None,
#   'result': {'loss': -0.889, 'status': 'ok'},
#   'misc': {'tid': 66,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [66], 'max_depth': [66], 'n_estimators': [66]},
#    'vals': {'criterion': [1], 'max_depth': [13.0], 'n_estimators': [2]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 7, 18, 16, 4, 46, 767000),
#   'refresh_time': datetime.datetime(2022, 7, 18, 16, 4, 49, 597000)},
#  {'state': 2,
#   'tid': 67,
#   'spec': None,
#   'result': {'loss': -0.8815, 'status': 'ok'},
#   'misc': {'tid': 67,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [67], 'max_depth': [67], 'n_estimators': [67]},
#    'vals': {'criterion': [1], 'max_depth': [12.0], 'n_estimators': [2]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 7, 18, 16, 4, 49, 605000),
#   'refresh_time': datetime.datetime(2022, 7, 18, 16, 4, 52, 431000)},
#  {'state': 2,
#   'tid': 68,
#   'spec': None,
#   'result': {'loss': -0.884, 'status': 'ok'},
#   'misc': {'tid': 68,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [68], 'max_depth': [68], 'n_estimators': [68]},
#    'vals': {'criterion': [1], 'max_depth': [13.0], 'n_estimators': [2]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 7, 18, 16, 4, 52, 441000),
#   'refresh_time': datetime.datetime(2022, 7, 18, 16, 4, 55, 300000)},
#  {'state': 2,
#   'tid': 69,
#   'spec': None,
#   'result': {'loss': -0.8815, 'status': 'ok'},
#   'misc': {'tid': 69,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [69], 'max_depth': [69], 'n_estimators': [69]},
#    'vals': {'criterion': [1], 'max_depth': [15.0], 'n_estimators': [2]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 7, 18, 16, 4, 55, 309000),
#   'refresh_time': datetime.datetime(2022, 7, 18, 16, 4, 58, 182000)},
#  {'state': 2,
#   'tid': 70,
#   'spec': None,
#   'result': {'loss': -0.8855000000000001, 'status': 'ok'},
#   'misc': {'tid': 70,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [70], 'max_depth': [70], 'n_estimators': [70]},
#    'vals': {'criterion': [1], 'max_depth': [13.0], 'n_estimators': [2]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 7, 18, 16, 4, 58, 191000),
#   'refresh_time': datetime.datetime(2022, 7, 18, 16, 5, 1, 99000)},
#  {'state': 2,
#   'tid': 71,
#   'spec': None,
#   'result': {'loss': -0.8865000000000001, 'status': 'ok'},
#   'misc': {'tid': 71,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [71], 'max_depth': [71], 'n_estimators': [71]},
#    'vals': {'criterion': [1], 'max_depth': [14.0], 'n_estimators': [5]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 7, 18, 16, 5, 1, 107000),
#   'refresh_time': datetime.datetime(2022, 7, 18, 16, 5, 6, 628000)},
#  {'state': 2,
#   'tid': 72,
#   'spec': None,
#   'result': {'loss': -0.8879999999999999, 'status': 'ok'},
#   'misc': {'tid': 72,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [72], 'max_depth': [72], 'n_estimators': [72]},
#    'vals': {'criterion': [1], 'max_depth': [12.0], 'n_estimators': [1]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 7, 18, 16, 5, 6, 636000),
#   'refresh_time': datetime.datetime(2022, 7, 18, 16, 5, 8, 483000)},
#  {'state': 2,
#   'tid': 73,
#   'spec': None,
#   'result': {'loss': -0.8775000000000001, 'status': 'ok'},
#   'misc': {'tid': 73,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [73], 'max_depth': [73], 'n_estimators': [73]},
#    'vals': {'criterion': [1], 'max_depth': [9.0], 'n_estimators': [2]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 7, 18, 16, 5, 8, 494000),
#   'refresh_time': datetime.datetime(2022, 7, 18, 16, 5, 11, 115000)},
#  {'state': 2,
#   'tid': 74,
#   'spec': None,
#   'result': {'loss': -0.8800000000000001, 'status': 'ok'},
#   'misc': {'tid': 74,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [74], 'max_depth': [74], 'n_estimators': [74]},
#    'vals': {'criterion': [1], 'max_depth': [11.0], 'n_estimators': [3]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 7, 18, 16, 5, 11, 124000),
#   'refresh_time': datetime.datetime(2022, 7, 18, 16, 5, 14, 673000)},
#  {'state': 2,
#   'tid': 75,
#   'spec': None,
#   'result': {'loss': -0.8825, 'status': 'ok'},
#   'misc': {'tid': 75,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [75], 'max_depth': [75], 'n_estimators': [75]},
#    'vals': {'criterion': [1], 'max_depth': [10.0], 'n_estimators': [2]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 7, 18, 16, 5, 14, 682000),
#   'refresh_time': datetime.datetime(2022, 7, 18, 16, 5, 17, 447000)},
#  {'state': 2,
#   'tid': 76,
#   'spec': None,
#   'result': {'loss': -0.883, 'status': 'ok'},
#   'misc': {'tid': 76,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [76], 'max_depth': [76], 'n_estimators': [76]},
#    'vals': {'criterion': [1], 'max_depth': [14.0], 'n_estimators': [5]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 7, 18, 16, 5, 17, 458000),
#   'refresh_time': datetime.datetime(2022, 7, 18, 16, 5, 23, 22000)},
#  {'state': 2,
#   'tid': 77,
#   'spec': None,
#   'result': {'loss': -0.8825, 'status': 'ok'},
#   'misc': {'tid': 77,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [77], 'max_depth': [77], 'n_estimators': [77]},
#    'vals': {'criterion': [1], 'max_depth': [13.0], 'n_estimators': [2]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 7, 18, 16, 5, 23, 32000),
#   'refresh_time': datetime.datetime(2022, 7, 18, 16, 5, 25, 939000)},
#  {'state': 2,
#   'tid': 78,
#   'spec': None,
#   'result': {'loss': -0.8805, 'status': 'ok'},
#   'misc': {'tid': 78,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [78], 'max_depth': [78], 'n_estimators': [78]},
#    'vals': {'criterion': [1], 'max_depth': [15.0], 'n_estimators': [0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 7, 18, 16, 5, 25, 949000),
#   'refresh_time': datetime.datetime(2022, 7, 18, 16, 5, 26, 956000)},
#  {'state': 2,
#   'tid': 79,
#   'spec': None,
#   'result': {'loss': -0.8800000000000001, 'status': 'ok'},
#   'misc': {'tid': 79,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [79], 'max_depth': [79], 'n_estimators': [79]},
#    'vals': {'criterion': [1], 'max_depth': [11.0], 'n_estimators': [1]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 7, 18, 16, 5, 26, 966000),
#   'refresh_time': datetime.datetime(2022, 7, 18, 16, 5, 28, 835000)},
#  {'state': 2,
#   'tid': 80,
#   'spec': None,
#   'result': {'loss': -0.892, 'status': 'ok'},
#   'misc': {'tid': 80,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [80], 'max_depth': [80], 'n_estimators': [80]},
#    'vals': {'criterion': [1], 'max_depth': [14.0], 'n_estimators': [2]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 7, 18, 16, 5, 28, 844000),
#   'refresh_time': datetime.datetime(2022, 7, 18, 16, 5, 31, 787000)},
#  {'state': 2,
#   'tid': 81,
#   'spec': None,
#   'result': {'loss': -0.877, 'status': 'ok'},
#   'misc': {'tid': 81,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [81], 'max_depth': [81], 'n_estimators': [81]},
#    'vals': {'criterion': [0], 'max_depth': [12.0], 'n_estimators': [3]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 7, 18, 16, 5, 31, 796000),
#   'refresh_time': datetime.datetime(2022, 7, 18, 16, 5, 34, 932000)},
#  {'state': 2,
#   'tid': 82,
#   'spec': None,
#   'result': {'loss': -0.8859999999999999, 'status': 'ok'},
#   'misc': {'tid': 82,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [82], 'max_depth': [82], 'n_estimators': [82]},
#    'vals': {'criterion': [1], 'max_depth': [14.0], 'n_estimators': [2]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 7, 18, 16, 5, 34, 941000),
#   'refresh_time': datetime.datetime(2022, 7, 18, 16, 5, 37, 837000)},
#  {'state': 2,
#   'tid': 83,
#   'spec': None,
#   'result': {'loss': -0.8865000000000001, 'status': 'ok'},
#   'misc': {'tid': 83,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [83], 'max_depth': [83], 'n_estimators': [83]},
#    'vals': {'criterion': [1], 'max_depth': [15.0], 'n_estimators': [5]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 7, 18, 16, 5, 37, 847000),
#   'refresh_time': datetime.datetime(2022, 7, 18, 16, 5, 43, 382000)},
#  {'state': 2,
#   'tid': 84,
#   'spec': None,
#   'result': {'loss': -0.8705, 'status': 'ok'},
#   'misc': {'tid': 84,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [84], 'max_depth': [84], 'n_estimators': [84]},
#    'vals': {'criterion': [1], 'max_depth': [8.0], 'n_estimators': [2]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 7, 18, 16, 5, 43, 392000),
#   'refresh_time': datetime.datetime(2022, 7, 18, 16, 5, 46, 20000)},
#  {'state': 2,
#   'tid': 85,
#   'spec': None,
#   'result': {'loss': -0.5615, 'status': 'ok'},
#   'misc': {'tid': 85,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [85], 'max_depth': [85], 'n_estimators': [85]},
#    'vals': {'criterion': [1], 'max_depth': [1.0], 'n_estimators': [0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 7, 18, 16, 5, 46, 31000),
#   'refresh_time': datetime.datetime(2022, 7, 18, 16, 5, 46, 649000)},
#  {'state': 2,
#   'tid': 86,
#   'spec': None,
#   'result': {'loss': -0.828, 'status': 'ok'},
#   'misc': {'tid': 86,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [86], 'max_depth': [86], 'n_estimators': [86]},
#    'vals': {'criterion': [0], 'max_depth': [4.0], 'n_estimators': [2]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 7, 18, 16, 5, 46, 658000),
#   'refresh_time': datetime.datetime(2022, 7, 18, 16, 5, 48, 556000)},
#  {'state': 2,
#   'tid': 87,
#   'spec': None,
#   'result': {'loss': -0.8815000000000002, 'status': 'ok'},
#   'misc': {'tid': 87,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [87], 'max_depth': [87], 'n_estimators': [87]},
#    'vals': {'criterion': [1], 'max_depth': [12.0], 'n_estimators': [1]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 7, 18, 16, 5, 48, 565000),
#   'refresh_time': datetime.datetime(2022, 7, 18, 16, 5, 50, 451000)},
#  {'state': 2,
#   'tid': 88,
#   'spec': None,
#   'result': {'loss': -0.8825, 'status': 'ok'},
#   'misc': {'tid': 88,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [88], 'max_depth': [88], 'n_estimators': [88]},
#    'vals': {'criterion': [1], 'max_depth': [13.0], 'n_estimators': [2]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 7, 18, 16, 5, 50, 462000),
#   'refresh_time': datetime.datetime(2022, 7, 18, 16, 5, 53, 312000)},
#  {'state': 2,
#   'tid': 89,
#   'spec': None,
#   'result': {'loss': -0.8789999999999999, 'status': 'ok'},
#   'misc': {'tid': 89,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [89], 'max_depth': [89], 'n_estimators': [89]},
#    'vals': {'criterion': [1], 'max_depth': [10.0], 'n_estimators': [3]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 7, 18, 16, 5, 53, 323000),
#   'refresh_time': datetime.datetime(2022, 7, 18, 16, 5, 56, 899000)},
#  {'state': 2,
#   'tid': 90,
#   'spec': None,
#   'result': {'loss': -0.8745, 'status': 'ok'},
#   'misc': {'tid': 90,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [90], 'max_depth': [90], 'n_estimators': [90]},
#    'vals': {'criterion': [0], 'max_depth': [9.0], 'n_estimators': [2]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 7, 18, 16, 5, 56, 908000),
#   'refresh_time': datetime.datetime(2022, 7, 18, 16, 5, 59, 227000)},
#  {'state': 2,
#   'tid': 91,
#   'spec': None,
#   'result': {'loss': -0.8845000000000001, 'status': 'ok'},
#   'misc': {'tid': 91,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [91], 'max_depth': [91], 'n_estimators': [91]},
#    'vals': {'criterion': [1], 'max_depth': [11.0], 'n_estimators': [5]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 7, 18, 16, 5, 59, 238000),
#   'refresh_time': datetime.datetime(2022, 7, 18, 16, 6, 4, 608000)},
#  {'state': 2,
#   'tid': 92,
#   'spec': None,
#   'result': {'loss': -0.8879999999999999, 'status': 'ok'},
#   'misc': {'tid': 92,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [92], 'max_depth': [92], 'n_estimators': [92]},
#    'vals': {'criterion': [1], 'max_depth': [15.0], 'n_estimators': [0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 7, 18, 16, 6, 4, 618000),
#   'refresh_time': datetime.datetime(2022, 7, 18, 16, 6, 5, 648000)},
#  {'state': 2,
#   'tid': 93,
#   'spec': None,
#   'result': {'loss': -0.882, 'status': 'ok'},
#   'misc': {'tid': 93,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [93], 'max_depth': [93], 'n_estimators': [93]},
#    'vals': {'criterion': [1], 'max_depth': [14.0], 'n_estimators': [2]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 7, 18, 16, 6, 5, 657000),
#   'refresh_time': datetime.datetime(2022, 7, 18, 16, 6, 8, 593000)},
#  {'state': 2,
#   'tid': 94,
#   'spec': None,
#   'result': {'loss': -0.884, 'status': 'ok'},
#   'misc': {'tid': 94,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [94], 'max_depth': [94], 'n_estimators': [94]},
#    'vals': {'criterion': [0], 'max_depth': [13.0], 'n_estimators': [2]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 7, 18, 16, 6, 8, 603000),
#   'refresh_time': datetime.datetime(2022, 7, 18, 16, 6, 11, 189000)},
#  {'state': 2,
#   'tid': 95,
#   'spec': None,
#   'result': {'loss': -0.865, 'status': 'ok'},
#   'misc': {'tid': 95,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [95], 'max_depth': [95], 'n_estimators': [95]},
#    'vals': {'criterion': [1], 'max_depth': [7.0], 'n_estimators': [1]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 7, 18, 16, 6, 11, 200000),
#   'refresh_time': datetime.datetime(2022, 7, 18, 16, 6, 12, 792000)},
#  {'state': 2,
#   'tid': 96,
#   'spec': None,
#   'result': {'loss': -0.8895, 'status': 'ok'},
#   'misc': {'tid': 96,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [96], 'max_depth': [96], 'n_estimators': [96]},
#    'vals': {'criterion': [1], 'max_depth': [15.0], 'n_estimators': [2]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 7, 18, 16, 6, 12, 802000),
#   'refresh_time': datetime.datetime(2022, 7, 18, 16, 6, 15, 733000)},
#  {'state': 2,
#   'tid': 97,
#   'spec': None,
#   'result': {'loss': -0.8855000000000001, 'status': 'ok'},
#   'misc': {'tid': 97,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [97], 'max_depth': [97], 'n_estimators': [97]},
#    'vals': {'criterion': [1], 'max_depth': [15.0], 'n_estimators': [3]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 7, 18, 16, 6, 15, 744000),
#   'refresh_time': datetime.datetime(2022, 7, 18, 16, 6, 19, 517000)},
#  {'state': 2,
#   'tid': 98,
#   'spec': None,
#   'result': {'loss': -0.8865000000000001, 'status': 'ok'},
#   'misc': {'tid': 98,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [98], 'max_depth': [98], 'n_estimators': [98]},
#    'vals': {'criterion': [1], 'max_depth': [14.0], 'n_estimators': [2]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 7, 18, 16, 6, 19, 527000),
#   'refresh_time': datetime.datetime(2022, 7, 18, 16, 6, 22, 421000)},
#  {'state': 2,
#   'tid': 99,
#   'spec': None,
#   'result': {'loss': -0.8755000000000001, 'status': 'ok'},
#   'misc': {'tid': 99,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [99], 'max_depth': [99], 'n_estimators': [99]},
#    'vals': {'criterion': [0], 'max_depth': [15.0], 'n_estimators': [2]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 7, 18, 16, 6, 22, 498000),
#   'refresh_time': datetime.datetime(2022, 7, 18, 16, 6, 25, 34000)}]

# %% [markdown]
# ## Попробуем использовать Спарк

# %%
from pyspark.sql import SparkSession
from hyperopt import SparkTrials
import os

# %%
# ! python -m venv pyspark_venv
# ! source pyspark_venv/bin/activate
# ! pip install sklearn hyperopt venv-pack
# ! venv-pack -o pyspark_venv.tar.gz

# %%
os.environ['PYSPARK_PYTHON'] = "path/to/python"

# %%
spark = SparkSession.builder. \
                    appName("my_test_app"). \
                    config(
                        "spark.yarn.dist.archives",  # 'spark.yarn.dist.archives' in YARN.
                        "pyspark_venv.tar.gz#environment").getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://rc1b-dataproc-m-w3hmr6la6zm49rsp.mdb.yandexcloud.net:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.0.3</code></dd>
#               <dt>Master</dt>
#                 <dd><code>yarn</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>my_test_app</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
# X_scaled_bc = scont.broadcast(list(X_scaled))
# y_bc = scont.broadcast(list(y))

# %% [markdown]
# Настроим гиперпараметры

# %%
def hyperparameter_tuning(params):
      # Get the broadcasted variables
#     X_scaled = X_scaled_bc.value
#     y = y_bc.value
    if 'max_depth' in params.keys():
        params['max_depth'] = int(params['max_depth'])
    clf = RandomForestClassifier(**params, n_jobs=-1)
    acc = cross_val_score(clf, X_scaled, y, scoring="accuracy").mean()
    return {"loss": -acc, "status": STATUS_OK}

# %% [markdown]
# Инициализация объекта испытания

# %%
trials = SparkTrials(parallelism=4)

# %%
best_spark = fmin(
    fn=hyperparameter_tuning,
    space = space, 
    algo=tpe.suggest, 
    max_evals=100, 
    trials=trials
)
# Out:
# 100%|██████████| 100/100 [04:01<00:00,  2.41s/trial, best loss: -0.8899999999999999]
# Total Trials: 100: 100 succeeded, 0 failed, 0 cancelled.

# %% [markdown]
# Лучшие параметры модели

# %%
best_spark
# Out:
# {'criterion': 1, 'max_depth': 13.0, 'n_estimators': 3}

# %%
# spark.stop()
