# %% [markdown]
# # SKLearn, joblib и joblibspark

# %% [markdown]
# Установим соответствующие пакеты

# %%
#!pip install findspark

# %% [markdown]
# Если установлен Spark, поищем где

# %%
import findspark
findspark.init()
findspark.find()
# Out:
# '/usr/lib/spark'

# %%
#! pip install joblibspark

# %%
import pandas as pd
import numpy as np
import scipy.stats as stats

from joblibspark import register_spark

from pyspark.ml.functions import vector_to_array

from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import StandardScaler 
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.utils import parallel_backend

# %% [markdown]
# Прочитаем данные

# %%
data = pd.read_csv('mob_price_data/train.csv')
data.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
#    three_g  touch_screen  wifi  price_range
# 0        0             0     1            1
# 1        1             1     0            2
# 2        1             1     0            2
# 3        1             0     0            2
# 4        1             1     0            1
#
# [5 rows x 21 columns]

# %% [markdown]
# Разделим данные на признаки и целевую переменную

# %%
X = data.drop("price_range", axis=1).values 
y = data.price_range.values

# %% [markdown]
# Стандартизуем признаки

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# Определим пространство поиска гиперпараметров

# %%
space = {
  "n_estimators": stats.randint(50, 150),
  "criterion": ["gini", "entropy"],
  "min_samples_leaf": stats.randint(1, 20),
  "min_samples_split": stats.uniform(0, 1)
}

n_evals = 200

# %% [markdown]
# ##  Подбор гиперпараметров на одном узле

# %%
model = RandomForestClassifier()

search = RandomizedSearchCV(
  estimator=model,
  param_distributions=space,
  n_iter=n_evals,
  n_jobs=1,
  cv=2,
  verbose=2
)
search.fit(X_scaled, y)
# Out:
# Fitting 2 folds for each of 200 candidates, totalling 400 fits
# [CV] criterion=gini, min_samples_leaf=13, min_samples_split=0.11269087426231938, n_estimators=74
# [CV]  criterion=gini, min_samples_leaf=13, min_samples_split=0.11269087426231938, n_estimators=74, total=   0.1s
# [CV] criterion=gini, min_samples_leaf=13, min_samples_split=0.11269087426231938, n_estimators=74
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.1s remaining:    0.0s
# [CV]  criterion=gini, min_samples_leaf=13, min_samples_split=0.11269087426231938, n_estimators=74, total=   0.1s
# [CV] criterion=entropy, min_samples_leaf=17, min_samples_split=0.3788483876280958, n_estimators=72
# [CV]  criterion=entropy, min_samples_leaf=17, min_samples_split=0.3788483876280958, n_estimators=72, total=   0.1s
# [CV] criterion=entropy, min_samples_leaf=17, min_samples_split=0.3788483876280958, n_estimators=72
# [CV]  criterion=entropy, min_samples_leaf=17, min_samples_split=0.3788483876280958, n_estimators=72, total=   0.1s
# [CV] criterion=entropy, min_samples_leaf=14, min_samples_split=0.6979710474461183, n_estimators=105
# [CV]  criterion=entropy, min_samples_leaf=14, min_samples_split=0.6979710474461183, n_estimators=105, total=   0.1s
# [CV] criterion=entropy, min_samples_leaf=14, min_samples_split=0.6979710474461183, n_estimators=105
# [CV]  criterion=entropy, min_samples_leaf=14, min_samples_split=0.6979710474461183, n_estimators=105, total=   0.1s
# [CV] criterion=gini, min_samples_leaf=18, min_samples_split=0.627281766236977, n_estimators=80
# [CV]  criterion=gini, min_samples_leaf=18, min_samples_split=0.627281766236977, n_estimators=80, total=   0.1s
# [CV] criterion=gini, min_samples_leaf=18, min_samples_split=0.627281766236977, n_estimators=80
# [CV]  criterion=gini, min_samples_leaf=18, min_samples_split=0.627281766236977, n_estimators=80, total=   0.1s
# [CV] criterion=entropy, min_samples_leaf=10, min_samples_split=0.35439976435560416, n_estimators=59
# [CV]  criterion=entropy, min_samples_leaf=10, min_samples_split=0.35439976435560416, n_estimators=59, total=   0.1s
# [CV] criterion=entropy, min_samples_leaf=10, min_samples_split=0.35439976435560416, n_estimators=59
# [CV]  criterion=entropy, min_samples_leaf=10, min_samples_split=0.35439976435560416, n_estimators=59, total=   0.1s
# [CV] criterion=gini, min_samples_leaf=14, min_samples_split=0.7313516293460912, n_estimators=147
# [CV]  criterion=gini, min_samples_leaf=14, min_samples_split=0.7313516293460912, n_estimators=147, total=   0.2s
# [CV] criterion=gini, min_samples_leaf=14, min_samples_split=0.7313516293460912, n_estimators=147
# [CV]  criterion=gini, min_samples_leaf=14, min_samples_split=0.7313516293460912, n_estimators=147, total=   0.2s
# [CV] criterion=gini, min_samples_leaf=17, min_samples_split=0.5084497689332579, n_estimators=116
# [CV]  criterion=gini, min_samples_leaf=17, min_samples_split=0.5084497689332579, n_estimators=116, total=   0.2s
# [CV] criterion=gini, min_samples_leaf=17, min_samples_split=0.5084497689332579, n_estimators=116
# [CV]  criterion=gini, min_samples_leaf=17, min_samples_split=0.5084497689332579, n_estimators=116, total=   0.2s
# [CV] criterion=gini, min_samples_leaf=6, min_samples_split=0.4074520297236026, n_estimators=106
# [CV]  criterion=gini, min_samples_leaf=6, min_samples_split=0.4074520297236026, n_estimators=106, total=   0.1s
# [CV] criterion=gini, min_samples_leaf=6, min_samples_split=0.4074520297236026, n_estimators=106
# [CV]  criterion=gini, min_samples_leaf=6, min_samples_split=0.4074520297236026, n_estimators=106, total=   0.1s
# [CV] criterion=entropy, min_samples_leaf=14, min_samples_split=0.07414376210345952, n_estimators=93
# [CV]  criterion=entropy, min_samples_leaf=14, min_samples_split=0.07414376210345952, n_estimators=93, total=   0.2s
# [CV] criterion=entropy, min_samples_leaf=14, min_samples_split=0.07414376210345952, n_estimators=93
# [CV]  criterion=entropy, min_samples_leaf=14, min_samples_split=0.07414376210345952, n_estimators=93, total=   0.2s
# [CV] criterion=gini, min_samples_leaf=19, min_samples_split=0.8861182048832562, n_estimators=64
# [CV]  criterion=gini, min_samples_leaf=19, min_samples_split=0.8861182048832562, n_estimators=64, total=   0.1s
# [CV] criterion=gini, min_samples_leaf=19, min_samples_split=0.8861182048832562, n_estimators=64
# [CV]  criterion=gini, min_samples_leaf=19, min_samples_split=0.8861182048832562, n_estimators=64, total=   0.1s
# [CV] criterion=gini, min_samples_leaf=6, min_samples_split=0.6159224580910849, n_estimators=83
# [CV]  criterion=gini, min_samples_leaf=6, min_samples_split=0.6159224580910849, n_estimators=83, total=   0.1s
# [CV] criterion=gini, min_samples_leaf=6, min_samples_split=0.6159224580910849, n_estimators=83
# [CV]  criterion=gini, min_samples_leaf=6, min_samples_split=0.6159224580910849, n_estimators=83, total=   0.1s
# [CV] criterion=entropy, min_samples_leaf=16, min_samples_split=0.29317172733470476, n_estimators=91
# [CV]  criterion=entropy, min_samples_leaf=16, min_samples_split=0.29317172733470476, n_estimators=91, total=   0.1s
# [CV] criterion=entropy, min_samples_leaf=16, min_samples_split=0.29317172733470476, n_estimators=91
# [CV]  criterion=entropy, min_samples_leaf=16, min_samples_split=0.29317172733470476, n_estimators=91, total=   0.1s
# [CV] criterion=gini, min_samples_leaf=11, min_samples_split=0.7478842870380245, n_estimators=132
# [CV]  criterion=gini, min_samples_leaf=11, min_samples_split=0.7478842870380245, n_estimators=132, total=   0.2s
# [CV] criterion=gini, min_samples_leaf=11, min_samples_split=0.7478842870380245, n_estimators=132
# [CV]  criterion=gini, min_samples_leaf=11, min_samples_split=0.7478842870380245, n_estimators=132, total=   0.2s
# [CV] criterion=entropy, min_samples_leaf=15, min_samples_split=0.5022294116358007, n_estimators=91
# [CV]  criterion=entropy, min_samples_leaf=15, min_samples_split=0.5022294116358007, n_estimators=91, total=   0.1s
# [CV] criterion=entropy, min_samples_leaf=15, min_samples_split=0.5022294116358007, n_estimators=91
# [CV]  criterion=entropy, min_samples_leaf=15, min_samples_split=0.5022294116358007, n_estimators=91, total=   0.1s
# [CV] criterion=entropy, min_samples_leaf=13, min_samples_split=0.9859076251515427, n_estimators=81
# [CV]  criterion=entropy, min_samples_leaf=13, min_samples_split=0.9859076251515427, n_estimators=81, total=   0.1s
# [CV] criterion=entropy, min_samples_leaf=13, min_samples_split=0.9859076251515427, n_estimators=81
# [CV]  criterion=entropy, min_samples_leaf=13, min_samples_split=0.9859076251515427, n_estimators=81, total=   0.1s
# [CV] criterion=entropy, min_samples_leaf=19, min_samples_split=0.9546742949990867, n_estimators=132
# [CV]  criterion=entropy, min_samples_leaf=19, min_samples_split=0.9546742949990867, n_estimators=132, total=   0.2s
# [CV] criterion=entropy, min_samples_leaf=19, min_samples_split=0.9546742949990867, n_estimators=132
# [CV]  criterion=entropy, min_samples_leaf=19, min_samples_split=0.9546742949990867, n_estimators=132, total=   0.2s
# [CV] criterion=gini, min_samples_leaf=10, min_samples_split=0.7149319165895793, n_estimators=112
# [CV]  criterion=gini, min_samples_leaf=10, min_samples_split=0.7149319165895793, n_estimators=112, total=   0.1s
# [CV] criterion=gini, min_samples_leaf=10, min_samples_split=0.7149319165895793, n_estimators=112
# [CV]  criterion=gini, min_samples_leaf=10, min_samples_split=0.7149319165895793, n_estimators=112, total=   0.1s
# [CV] criterion=entropy, min_samples_leaf=1, min_samples_split=0.6692049384891939, n_estimators=79
# [CV]  criterion=entropy, min_samples_leaf=1, min_samples_split=0.6692049384891939, n_estimators=79, total=   0.1s
# [CV] criterion=entropy, min_samples_leaf=1, min_samples_split=0.6692049384891939, n_estimators=79
# [CV]  criterion=entropy, min_samples_leaf=1, min_samples_split=0.6692049384891939, n_estimators=79, total=   0.1s
# [CV] criterion=entropy, min_samples_leaf=14, min_samples_split=0.633711145518367, n_estimators=119
# [CV]  criterion=entropy, min_samples_leaf=14, min_samples_split=0.633711145518367, n_estimators=119, total=   0.1s
# [CV] criterion=entropy, min_samples_leaf=14, min_samples_split=0.633711145518367, n_estimators=119
# [CV]  criterion=entropy, min_samples_leaf=14, min_samples_split=0.633711145518367, n_estimators=119, total=   0.1s
# [CV] criterion=entropy, min_samples_leaf=4, min_samples_split=0.9667798940189872, n_estimators=106
# [CV]  criterion=entropy, min_samples_leaf=4, min_samples_split=0.9667798940189872, n_estimators=106, total=   0.1s
# [CV] criterion=entropy, min_samples_leaf=4, min_samples_split=0.9667798940189872, n_estimators=106
# [CV]  criterion=entropy, min_samples_leaf=4, min_samples_split=0.9667798940189872, n_estimators=106, total=   0.1s
# [CV] criterion=entropy, min_samples_leaf=11, min_samples_split=0.4957360917687489, n_estimators=146
# [CV]  criterion=entropy, min_samples_leaf=11, min_samples_split=0.4957360917687489, n_estimators=146, total=   0.2s
# [CV] criterion=entropy, min_samples_leaf=11, min_samples_split=0.4957360917687489, n_estimators=146
# [CV]  criterion=entropy, min_samples_leaf=11, min_samples_split=0.4957360917687489, n_estimators=146, total=   0.2s
# [CV] criterion=entropy, min_samples_leaf=2, min_samples_split=0.4170353442623693, n_estimators=104
# [CV]  criterion=entropy, min_samples_leaf=2, min_samples_split=0.4170353442623693, n_estimators=104, total=   0.1s
# [CV] criterion=entropy, min_samples_leaf=2, min_samples_split=0.4170353442623693, n_estimators=104
# [CV]  criterion=entropy, min_samples_leaf=2, min_samples_split=0.4170353442623693, n_estimators=104, total=   0.1s
# [CV] criterion=gini, min_samples_leaf=12, min_samples_split=0.9641297450008189, n_estimators=91
# [CV]  criterion=gini, min_samples_leaf=12, min_samples_split=0.9641297450008189, n_estimators=91, total=   0.1s
# [CV] criterion=gini, min_samples_leaf=12, min_samples_split=0.9641297450008189, n_estimators=91
# [CV]  criterion=gini, min_samples_leaf=12, min_samples_split=0.9641297450008189, n_estimators=91, total=   0.1s
# [CV] criterion=gini, min_samples_leaf=10, min_samples_split=0.5777808061602624, n_estimators=61
# [CV]  criterion=gini, min_samples_leaf=10, min_samples_split=0.5777808061602624, n_estimators=61, total=   0.1s
# [CV] criterion=gini, min_samples_leaf=10, min_samples_split=0.5777808061602624, n_estimators=61
# [CV]  criterion=gini, min_samples_leaf=10, min_samples_split=0.5777808061602624, n_estimators=61, total=   0.1s
# [CV] criterion=gini, min_samples_leaf=15, min_samples_split=0.20405395485504063, n_estimators=99
# [CV]  criterion=gini, min_samples_leaf=15, min_samples_split=0.20405395485504063, n_estimators=99, total=   0.2s
# [CV] criterion=gini, min_samples_leaf=15, min_samples_split=0.20405395485504063, n_estimators=99
# [CV]  criterion=gini, min_samples_leaf=15, min_samples_split=0.20405395485504063, n_estimators=99, total=   0.2s
# [CV] criterion=entropy, min_samples_leaf=8, min_samples_split=0.20788817237979262, n_estimators=102
# [CV]  criterion=entropy, min_samples_leaf=8, min_samples_split=0.20788817237979262, n_estimators=102, total=   0.2s
# [CV] criterion=entropy, min_samples_leaf=8, min_samples_split=0.20788817237979262, n_estimators=102
# [CV]  criterion=entropy, min_samples_leaf=8, min_samples_split=0.20788817237979262, n_estimators=102, total=   0.2s
# [CV] criterion=gini, min_samples_leaf=1, min_samples_split=0.055934252507118365, n_estimators=123
# [CV]  criterion=gini, min_samples_leaf=1, min_samples_split=0.055934252507118365, n_estimators=123, total=   0.2s
# [CV] criterion=gini, min_samples_leaf=1, min_samples_split=0.055934252507118365, n_estimators=123
# [CV]  criterion=gini, min_samples_leaf=1, min_samples_split=0.055934252507118365, n_estimators=123, total=   0.2s
# [CV] criterion=gini, min_samples_leaf=5, min_samples_split=0.6883813129753691, n_estimators=72
# [CV]  criterion=gini, min_samples_leaf=5, min_samples_split=0.6883813129753691, n_estimators=72, total=   0.1s
# [CV] criterion=gini, min_samples_leaf=5, min_samples_split=0.6883813129753691, n_estimators=72
# [CV]  criterion=gini, min_samples_leaf=5, min_samples_split=0.6883813129753691, n_estimators=72, total=   0.1s
# [CV] criterion=gini, min_samples_leaf=7, min_samples_split=0.3552325791550276, n_estimators=141
# [CV]  criterion=gini, min_samples_leaf=7, min_samples_split=0.3552325791550276, n_estimators=141, total=   0.2s
# [CV] criterion=gini, min_samples_leaf=7, min_samples_split=0.3552325791550276, n_estimators=141
# [CV]  criterion=gini, min_samples_leaf=7, min_samples_split=0.3552325791550276, n_estimators=141, total=   0.2s
# [CV] criterion=entropy, min_samples_leaf=10, min_samples_split=0.38825527945557736, n_estimators=103
# [CV]  criterion=entropy, min_samples_leaf=10, min_samples_split=0.38825527945557736, n_estimators=103, total=   0.1s
# [CV] criterion=entropy, min_samples_leaf=10, min_samples_split=0.38825527945557736, n_estimators=103
# [CV]  criterion=entropy, min_samples_leaf=10, min_samples_split=0.38825527945557736, n_estimators=103, total=   0.1s
# [CV] criterion=gini, min_samples_leaf=10, min_samples_split=0.09516409248500068, n_estimators=115
# [CV]  criterion=gini, min_samples_leaf=10, min_samples_split=0.09516409248500068, n_estimators=115, total=   0.2s
# [CV] criterion=gini, min_samples_leaf=10, min_samples_split=0.09516409248500068, n_estimators=115
# [CV]  criterion=gini, min_samples_leaf=10, min_samples_split=0.09516409248500068, n_estimators=115, total=   0.2s
# [CV] criterion=entropy, min_samples_leaf=6, min_samples_split=0.2590824387923818, n_estimators=55
# [CV]  criterion=entropy, min_samples_leaf=6, min_samples_split=0.2590824387923818, n_estimators=55, total=   0.1s
# [CV] criterion=entropy, min_samples_leaf=6, min_samples_split=0.2590824387923818, n_estimators=55
# [CV]  criterion=entropy, min_samples_leaf=6, min_samples_split=0.2590824387923818, n_estimators=55, total=   0.1s
# [CV] criterion=gini, min_samples_leaf=4, min_samples_split=0.5210540047291725, n_estimators=74
# [CV]  criterion=gini, min_samples_leaf=4, min_samples_split=0.5210540047291725, n_estimators=74, total=   0.1s
# [CV] criterion=gini, min_samples_leaf=4, min_samples_split=0.5210540047291725, n_estimators=74
# [CV]  criterion=gini, min_samples_leaf=4, min_samples_split=0.5210540047291725, n_estimators=74, total=   0.1s
# [CV] criterion=entropy, min_samples_leaf=15, min_samples_split=0.4631273274580877, n_estimators=116
# [CV]  criterion=entropy, min_samples_leaf=15, min_samples_split=0.4631273274580877, n_estimators=116, total=   0.2s
# [CV] criterion=entropy, min_samples_leaf=15, min_samples_split=0.4631273274580877, n_estimators=116
# [CV]  criterion=entropy, min_samples_leaf=15, min_samples_split=0.4631273274580877, n_estimators=116, total=   0.2s
# [CV] criterion=gini, min_samples_leaf=3, min_samples_split=0.6232629514852592, n_estimators=107
# [CV]  criterion=gini, min_samples_leaf=3, min_samples_split=0.6232629514852592, n_estimators=107, total=   0.1s
# [CV] criterion=gini, min_samples_leaf=3, min_samples_split=0.6232629514852592, n_estimators=107
# [CV]  criterion=gini, min_samples_leaf=3, min_samples_split=0.6232629514852592, n_estimators=107, total=   0.1s
# [CV] criterion=entropy, min_samples_leaf=3, min_samples_split=0.35726941072172047, n_estimators=102
# [CV]  criterion=entropy, min_samples_leaf=3, min_samples_split=0.35726941072172047, n_estimators=102, total=   0.1s
# [CV] criterion=entropy, min_samples_leaf=3, min_samples_split=0.35726941072172047, n_estimators=102
# [CV]  criterion=entropy, min_samples_leaf=3, min_samples_split=0.35726941072172047, n_estimators=102, total=   0.2s
# [CV] criterion=entropy, min_samples_leaf=8, min_samples_split=0.915694094478268, n_estimators=127
# [CV]  criterion=entropy, min_samples_leaf=8, min_samples_split=0.915694094478268, n_estimators=127, total=   0.1s
# [CV] criterion=entropy, min_samples_leaf=8, min_samples_split=0.915694094478268, n_estimators=127
# [CV]  criterion=entropy, min_samples_leaf=8, min_samples_split=0.915694094478268, n_estimators=127, total=   0.1s
# [CV] criterion=entropy, min_samples_leaf=16, min_samples_split=0.04819810237330058, n_estimators=88
# [CV]  criterion=entropy, min_samples_leaf=16, min_samples_split=0.04819810237330058, n_estimators=88, total=   0.2s
# [CV] criterion=entropy, min_samples_leaf=16, min_samples_split=0.04819810237330058, n_estimators=88
# [CV]  criterion=entropy, min_samples_leaf=16, min_samples_split=0.04819810237330058, n_estimators=88, total=   0.2s
# [CV] criterion=entropy, min_samples_leaf=17, min_samples_split=0.22996564984053958, n_estimators=117
# [CV]  criterion=entropy, min_samples_leaf=17, min_samples_split=0.22996564984053958, n_estimators=117, total=   0.2s
# [CV] criterion=entropy, min_samples_leaf=17, min_samples_split=0.22996564984053958, n_estimators=117
# [CV]  criterion=entropy, min_samples_leaf=17, min_samples_split=0.22996564984053958, n_estimators=117, total=   0.2s
# [CV] criterion=gini, min_samples_leaf=17, min_samples_split=0.4843353138477261, n_estimators=142
# [CV]  criterion=gini, min_samples_leaf=17, min_samples_split=0.4843353138477261, n_estimators=142, total=   0.2s
# [CV] criterion=gini, min_samples_leaf=17, min_samples_split=0.4843353138477261, n_estimators=142
# [CV]  criterion=gini, min_samples_leaf=17, min_samples_split=0.4843353138477261, n_estimators=142, total=   0.2s
# [CV] criterion=entropy, min_samples_leaf=5, min_samples_split=0.8097480601038972, n_estimators=84
# [CV]  criterion=entropy, min_samples_leaf=5, min_samples_split=0.8097480601038972, n_estimators=84, total=   0.1s
# [CV] criterion=entropy, min_samples_leaf=5, min_samples_split=0.8097480601038972, n_estimators=84
# [CV]  criterion=entropy, min_samples_leaf=5, min_samples_split=0.8097480601038972, n_estimators=84, total=   0.1s
# [CV] criterion=entropy, min_samples_leaf=8, min_samples_split=0.12705664570141606, n_estimators=56
# [CV]  criterion=entropy, min_samples_leaf=8, min_samples_split=0.12705664570141606, n_estimators=56, total=   0.1s
# [CV] criterion=entropy, min_samples_leaf=8, min_samples_split=0.12705664570141606, n_estimators=56
# [CV]  criterion=entropy, min_samples_leaf=8, min_samples_split=0.12705664570141606, n_estimators=56, total=   0.1s
# [CV] criterion=entropy, min_samples_leaf=1, min_samples_split=0.34644428620819523, n_estimators=86
# [CV]  criterion=entropy, min_samples_leaf=1, min_samples_split=0.34644428620819523, n_estimators=86, total=   0.1s
# [CV] criterion=entropy, min_samples_leaf=1, min_samples_split=0.34644428620819523, n_estimators=86
# [CV]  criterion=entropy, min_samples_leaf=1, min_samples_split=0.34644428620819523, n_estimators=86, total=   0.1s
# [CV] criterion=entropy, min_samples_leaf=15, min_samples_split=0.6470915467167544, n_estimators=144
# [CV]  criterion=entropy, min_samples_leaf=15, min_samples_split=0.6470915467167544, n_estimators=144, total=   0.2s
# [CV] criterion=entropy, min_samples_leaf=15, min_samples_split=0.6470915467167544, n_estimators=144
# [CV]  criterion=entropy, min_samples_leaf=15, min_samples_split=0.6470915467167544, n_estimators=144, total=   0.2s
# [CV] criterion=entropy, min_samples_leaf=15, min_samples_split=0.047093606796312026, n_estimators=112
# [CV]  criterion=entropy, min_samples_leaf=15, min_samples_split=0.047093606796312026, n_estimators=112, total=   0.2s
# [CV] criterion=entropy, min_samples_leaf=15, min_samples_split=0.047093606796312026, n_estimators=112
# [CV]  criterion=entropy, min_samples_leaf=15, min_samples_split=0.047093606796312026, n_estimators=112, total=   0.2s
# [CV] criterion=entropy, min_samples_leaf=9, min_samples_split=0.7788670630304929, n_estimators=138
# [CV]  criterion=entropy, min_samples_leaf=9, min_samples_split=0.7788670630304929, n_estimators=138, total=   0.2s
# [CV] criterion=entropy, min_samples_leaf=9, min_samples_split=0.7788670630304929, n_estimators=138
# [CV]  criterion=entropy, min_samples_leaf=9, min_samples_split=0.7788670630304929, n_estimators=138, total=   0.2s
# [CV] criterion=gini, min_samples_leaf=6, min_samples_split=0.9885859670476775, n_estimators=102
# [CV]  criterion=gini, min_samples_leaf=6, min_samples_split=0.9885859670476775, n_estimators=102, total=   0.1s
# [CV] criterion=gini, min_samples_leaf=6, min_samples_split=0.9885859670476775, n_estimators=102
# [CV]  criterion=gini, min_samples_leaf=6, min_samples_split=0.9885859670476775, n_estimators=102, total=   0.1s
# [CV] criterion=gini, min_samples_leaf=3, min_samples_split=0.7615199923513059, n_estimators=126
# [CV]  criterion=gini, min_samples_leaf=3, min_samples_split=0.7615199923513059, n_estimators=126, total=   0.1s
# [CV] criterion=gini, min_samples_leaf=3, min_samples_split=0.7615199923513059, n_estimators=126
# [CV]  criterion=gini, min_samples_leaf=3, min_samples_split=0.7615199923513059, n_estimators=126, total=   0.1s
# [CV] criterion=gini, min_samples_leaf=4, min_samples_split=0.6961754644189118, n_estimators=62
# [CV]  criterion=gini, min_samples_leaf=4, min_samples_split=0.6961754644189118, n_estimators=62, total=   0.1s
# [CV] criterion=gini, min_samples_leaf=4, min_samples_split=0.6961754644189118, n_estimators=62
# [CV]  criterion=gini, min_samples_leaf=4, min_samples_split=0.6961754644189118, n_estimators=62, total=   0.1s
# [CV] criterion=gini, min_samples_leaf=12, min_samples_split=0.9575941697305196, n_estimators=51
# [CV]  criterion=gini, min_samples_leaf=12, min_samples_split=0.9575941697305196, n_estimators=51, total=   0.1s
# [CV] criterion=gini, min_samples_leaf=12, min_samples_split=0.9575941697305196, n_estimators=51
# [CV]  criterion=gini, min_samples_leaf=12, min_samples_split=0.9575941697305196, n_estimators=51, total=   0.1s
# [CV] criterion=gini, min_samples_leaf=4, min_samples_split=0.08147814395754116, n_estimators=86
# [CV]  criterion=gini, min_samples_leaf=4, min_samples_split=0.08147814395754116, n_estimators=86, total=   0.1s
# [CV] criterion=gini, min_samples_leaf=4, min_samples_split=0.08147814395754116, n_estimators=86
# [CV]  criterion=gini, min_samples_leaf=4, min_samples_split=0.08147814395754116, n_estimators=86, total=   0.1s
# [CV] criterion=gini, min_samples_leaf=12, min_samples_split=0.010951022211157069, n_estimators=77
# [CV]  criterion=gini, min_samples_leaf=12, min_samples_split=0.010951022211157069, n_estimators=77, total=   0.1s
# [CV] criterion=gini, min_samples_leaf=12, min_samples_split=0.010951022211157069, n_estimators=77
# [CV]  criterion=gini, min_samples_leaf=12, min_samples_split=0.010951022211157069, n_estimators=77, total=   0.1s
# [CV] criterion=gini, min_samples_leaf=2, min_samples_split=0.45658316760331374, n_estimators=132
# [CV]  criterion=gini, min_samples_leaf=2, min_samples_split=0.45658316760331374, n_estimators=132, total=   0.2s
# [CV] criterion=gini, min_samples_leaf=2, min_samples_split=0.45658316760331374, n_estimators=132
# [CV]  criterion=gini, min_samples_leaf=2, min_samples_split=0.45658316760331374, n_estimators=132, total=   0.2s
# [CV] criterion=gini, min_samples_leaf=7, min_samples_split=0.2665754056666364, n_estimators=64
# [CV]  criterion=gini, min_samples_leaf=7, min_samples_split=0.2665754056666364, n_estimators=64, total=   0.1s
# [CV] criterion=gini, min_samples_leaf=7, min_samples_split=0.2665754056666364, n_estimators=64
# [CV]  criterion=gini, min_samples_leaf=7, min_samples_split=0.2665754056666364, n_estimators=64, total=   0.1s
# [CV] criterion=entropy, min_samples_leaf=17, min_samples_split=0.8996351025794238, n_estimators=93
# [CV]  criterion=entropy, min_samples_leaf=17, min_samples_split=0.8996351025794238, n_estimators=93, total=   0.1s
# [CV] criterion=entropy, min_samples_leaf=17, min_samples_split=0.8996351025794238, n_estimators=93
# [CV]  criterion=entropy, min_samples_leaf=17, min_samples_split=0.8996351025794238, n_estimators=93, total=   0.1s
# [CV] criterion=entropy, min_samples_leaf=16, min_samples_split=0.2746989267108976, n_estimators=121
# [CV]  criterion=entropy, min_samples_leaf=16, min_samples_split=0.2746989267108976, n_estimators=121, total=   0.2s
# [CV] criterion=entropy, min_samples_leaf=16, min_samples_split=0.2746989267108976, n_estimators=121
# [CV]  criterion=entropy, min_samples_leaf=16, min_samples_split=0.2746989267108976, n_estimators=121, total=   0.2s
# [CV] criterion=entropy, min_samples_leaf=3, min_samples_split=0.21534255156980753, n_estimators=149
# [CV]  criterion=entropy, min_samples_leaf=3, min_samples_split=0.21534255156980753, n_estimators=149, total=   0.2s
# [CV] criterion=entropy, min_samples_leaf=3, min_samples_split=0.21534255156980753, n_estimators=149
# [CV]  criterion=entropy, min_samples_leaf=3, min_samples_split=0.21534255156980753, n_estimators=149, total=   0.2s
# [CV] criterion=gini, min_samples_leaf=11, min_samples_split=0.03779239263554335, n_estimators=115
# [CV]  criterion=gini, min_samples_leaf=11, min_samples_split=0.03779239263554335, n_estimators=115, total=   0.2s
# [CV] criterion=gini, min_samples_leaf=11, min_samples_split=0.03779239263554335, n_estimators=115
# [CV]  criterion=gini, min_samples_leaf=11, min_samples_split=0.03779239263554335, n_estimators=115, total=   0.2s
# [CV] criterion=entropy, min_samples_leaf=5, min_samples_split=0.07089753867026094, n_estimators=57
# [CV]  criterion=entropy, min_samples_leaf=5, min_samples_split=0.07089753867026094, n_estimators=57, total=   0.1s
# [CV] criterion=entropy, min_samples_leaf=5, min_samples_split=0.07089753867026094, n_estimators=57
# [CV]  criterion=entropy, min_samples_leaf=5, min_samples_split=0.07089753867026094, n_estimators=57, total=   0.1s
# [CV] criterion=entropy, min_samples_leaf=6, min_samples_split=0.20118682649066622, n_estimators=125
# [CV]  criterion=entropy, min_samples_leaf=6, min_samples_split=0.20118682649066622, n_estimators=125, total=   0.2s
# [CV] criterion=entropy, min_samples_leaf=6, min_samples_split=0.20118682649066622, n_estimators=125
# [CV]  criterion=entropy, min_samples_leaf=6, min_samples_split=0.20118682649066622, n_estimators=125, total=   0.2s
# [CV] criterion=entropy, min_samples_leaf=19, min_samples_split=0.5587393871335963, n_estimators=115
# [CV]  criterion=entropy, min_samples_leaf=19, min_samples_split=0.5587393871335963, n_estimators=115, total=   0.2s
# [CV] criterion=entropy, min_samples_leaf=19, min_samples_split=0.5587393871335963, n_estimators=115
# [CV]  criterion=entropy, min_samples_leaf=19, min_samples_split=0.5587393871335963, n_estimators=115, total=   0.2s
# [CV] criterion=gini, min_samples_leaf=16, min_samples_split=0.0682899309452738, n_estimators=106
# [CV]  criterion=gini, min_samples_leaf=16, min_samples_split=0.0682899309452738, n_estimators=106, total=   0.2s
# [CV] criterion=gini, min_samples_leaf=16, min_samples_split=0.0682899309452738, n_estimators=106
# [CV]  criterion=gini, min_samples_leaf=16, min_samples_split=0.0682899309452738, n_estimators=106, total=   0.2s
# [CV] criterion=gini, min_samples_leaf=12, min_samples_split=0.9341253910749091, n_estimators=73
# [CV]  criterion=gini, min_samples_leaf=12, min_samples_split=0.9341253910749091, n_estimators=73, total=   0.1s
# [CV] criterion=gini, min_samples_leaf=12, min_samples_split=0.9341253910749091, n_estimators=73
# [CV]  criterion=gini, min_samples_leaf=12, min_samples_split=0.9341253910749091, n_estimators=73, total=   0.1s
# [CV] criterion=gini, min_samples_leaf=11, min_samples_split=0.038183461339528324, n_estimators=129
# [CV]  criterion=gini, min_samples_leaf=11, min_samples_split=0.038183461339528324, n_estimators=129, total=   0.2s
# [CV] criterion=gini, min_samples_leaf=11, min_samples_split=0.038183461339528324, n_estimators=129
# [CV]  criterion=gini, min_samples_leaf=11, min_samples_split=0.038183461339528324, n_estimators=129, total=   0.2s
# [CV] criterion=entropy, min_samples_leaf=5, min_samples_split=0.6766509229592708, n_estimators=50
# [CV]  criterion=entropy, min_samples_leaf=5, min_samples_split=0.6766509229592708, n_estimators=50, total=   0.1s
# [CV] criterion=entropy, min_samples_leaf=5, min_samples_split=0.6766509229592708, n_estimators=50
# [CV]  criterion=entropy, min_samples_leaf=5, min_samples_split=0.6766509229592708, n_estimators=50, total=   0.1s
# [CV] criterion=entropy, min_samples_leaf=4, min_samples_split=0.5799098000989424, n_estimators=111
# [CV]  criterion=entropy, min_samples_leaf=4, min_samples_split=0.5799098000989424, n_estimators=111, total=   0.2s
# [CV] criterion=entropy, min_samples_leaf=4, min_samples_split=0.5799098000989424, n_estimators=111
# [CV]  criterion=entropy, min_samples_leaf=4, min_samples_split=0.5799098000989424, n_estimators=111, total=   0.2s
# [CV] criterion=entropy, min_samples_leaf=5, min_samples_split=0.30170492677147887, n_estimators=88
# [CV]  criterion=entropy, min_samples_leaf=5, min_samples_split=0.30170492677147887, n_estimators=88, total=   0.1s
# [CV] criterion=entropy, min_samples_leaf=5, min_samples_split=0.30170492677147887, n_estimators=88
# [CV]  criterion=entropy, min_samples_leaf=5, min_samples_split=0.30170492677147887, n_estimators=88, total=   0.1s
# [CV] criterion=entropy, min_samples_leaf=10, min_samples_split=0.3572533969529563, n_estimators=102
# [CV]  criterion=entropy, min_samples_leaf=10, min_samples_split=0.3572533969529563, n_estimators=102, total=   0.1s
# [CV] criterion=entropy, min_samples_leaf=10, min_samples_split=0.3572533969529563, n_estimators=102
# [CV]  criterion=entropy, min_samples_leaf=10, min_samples_split=0.3572533969529563, n_estimators=102, total=   0.1s
# [CV] criterion=entropy, min_samples_leaf=9, min_samples_split=0.8728577879189239, n_estimators=128
# [CV]  criterion=entropy, min_samples_leaf=9, min_samples_split=0.8728577879189239, n_estimators=128, total=   0.2s
# [CV] criterion=entropy, min_samples_leaf=9, min_samples_split=0.8728577879189239, n_estimators=128
# [CV]  criterion=entropy, min_samples_leaf=9, min_samples_split=0.8728577879189239, n_estimators=128, total=   0.2s
# [CV] criterion=gini, min_samples_leaf=1, min_samples_split=0.3151732537115304, n_estimators=144
# [CV]  criterion=gini, min_samples_leaf=1, min_samples_split=0.3151732537115304, n_estimators=144, total=   0.2s
# [CV] criterion=gini, min_samples_leaf=1, min_samples_split=0.3151732537115304, n_estimators=144
# [CV]  criterion=gini, min_samples_leaf=1, min_samples_split=0.3151732537115304, n_estimators=144, total=   0.2s
# [CV] criterion=gini, min_samples_leaf=4, min_samples_split=0.3063980270722245, n_estimators=117
# [CV]  criterion=gini, min_samples_leaf=4, min_samples_split=0.3063980270722245, n_estimators=117, total=   0.2s
# [CV] criterion=gini, min_samples_leaf=4, min_samples_split=0.3063980270722245, n_estimators=117
# [CV]  criterion=gini, min_samples_leaf=4, min_samples_split=0.3063980270722245, n_estimators=117, total=   0.2s
# [CV] criterion=gini, min_samples_leaf=2, min_samples_split=0.9071850462767794, n_estimators=111
# [CV]  criterion=gini, min_samples_leaf=2, min_samples_split=0.9071850462767794, n_estimators=111, total=   0.1s
# [CV] criterion=gini, min_samples_leaf=2, min_samples_split=0.9071850462767794, n_estimators=111
# [CV]  criterion=gini, min_samples_leaf=2, min_samples_split=0.9071850462767794, n_estimators=111, total=   0.1s
# [CV] criterion=entropy, min_samples_leaf=7, min_samples_split=0.16843841172013962, n_estimators=62
# [CV]  criterion=entropy, min_samples_leaf=7, min_samples_split=0.16843841172013962, n_estimators=62, total=   0.1s
# [CV] criterion=entropy, min_samples_leaf=7, min_samples_split=0.16843841172013962, n_estimators=62
# [CV]  criterion=entropy, min_samples_leaf=7, min_samples_split=0.16843841172013962, n_estimators=62, total=   0.1s
# [CV] criterion=gini, min_samples_leaf=6, min_samples_split=0.9194972551831088, n_estimators=130
# [CV]  criterion=gini, min_samples_leaf=6, min_samples_split=0.9194972551831088, n_estimators=130, total=   0.2s
# [CV] criterion=gini, min_samples_leaf=6, min_samples_split=0.9194972551831088, n_estimators=130
# [CV]  criterion=gini, min_samples_leaf=6, min_samples_split=0.9194972551831088, n_estimators=130, total=   0.2s
# [CV] criterion=entropy, min_samples_leaf=10, min_samples_split=0.05705359367151075, n_estimators=118
# [CV]  criterion=entropy, min_samples_leaf=10, min_samples_split=0.05705359367151075, n_estimators=118, total=   0.2s
# [CV] criterion=entropy, min_samples_leaf=10, min_samples_split=0.05705359367151075, n_estimators=118
# [CV]  criterion=entropy, min_samples_leaf=10, min_samples_split=0.05705359367151075, n_estimators=118, total=   0.2s
# [CV] criterion=entropy, min_samples_leaf=17, min_samples_split=0.20820787496865867, n_estimators=110
# [CV]  criterion=entropy, min_samples_leaf=17, min_samples_split=0.20820787496865867, n_estimators=110, total=   0.2s
# [CV] criterion=entropy, min_samples_leaf=17, min_samples_split=0.20820787496865867, n_estimators=110
# [CV]  criterion=entropy, min_samples_leaf=17, min_samples_split=0.20820787496865867, n_estimators=110, total=   0.2s
# [CV] criterion=gini, min_samples_leaf=15, min_samples_split=0.18869767572926255, n_estimators=110
# [CV]  criterion=gini, min_samples_leaf=15, min_samples_split=0.18869767572926255, n_estimators=110, total=   0.2s
# [CV] criterion=gini, min_samples_leaf=15, min_samples_split=0.18869767572926255, n_estimators=110
# [CV]  criterion=gini, min_samples_leaf=15, min_samples_split=0.18869767572926255, n_estimators=110, total=   0.2s
# [CV] criterion=gini, min_samples_leaf=13, min_samples_split=0.9424600008560727, n_estimators=57
# [CV]  criterion=gini, min_samples_leaf=13, min_samples_split=0.9424600008560727, n_estimators=57, total=   0.1s
# [CV] criterion=gini, min_samples_leaf=13, min_samples_split=0.9424600008560727, n_estimators=57
# [CV]  criterion=gini, min_samples_leaf=13, min_samples_split=0.9424600008560727, n_estimators=57, total=   0.1s
# [CV] criterion=entropy, min_samples_leaf=3, min_samples_split=0.5209217604097969, n_estimators=117
# [CV]  criterion=entropy, min_samples_leaf=3, min_samples_split=0.5209217604097969, n_estimators=117, total=   0.2s
# [CV] criterion=entropy, min_samples_leaf=3, min_samples_split=0.5209217604097969, n_estimators=117
# [CV]  criterion=entropy, min_samples_leaf=3, min_samples_split=0.5209217604097969, n_estimators=117, total=   0.2s
# [CV] criterion=entropy, min_samples_leaf=11, min_samples_split=0.9826730019021503, n_estimators=94
# [CV]  criterion=entropy, min_samples_leaf=11, min_samples_split=0.9826730019021503, n_estimators=94, total=   0.1s
# [CV] criterion=entropy, min_samples_leaf=11, min_samples_split=0.9826730019021503, n_estimators=94
# [CV]  criterion=entropy, min_samples_leaf=11, min_samples_split=0.9826730019021503, n_estimators=94, total=   0.1s
# [CV] criterion=gini, min_samples_leaf=10, min_samples_split=0.15219178539893807, n_estimators=86
# [CV]  criterion=gini, min_samples_leaf=10, min_samples_split=0.15219178539893807, n_estimators=86, total=   0.1s
# [CV] criterion=gini, min_samples_leaf=10, min_samples_split=0.15219178539893807, n_estimators=86
# [CV]  criterion=gini, min_samples_leaf=10, min_samples_split=0.15219178539893807, n_estimators=86, total=   0.1s
# [CV] criterion=gini, min_samples_leaf=19, min_samples_split=0.6808343088034366, n_estimators=131
# [CV]  criterion=gini, min_samples_leaf=19, min_samples_split=0.6808343088034366, n_estimators=131, total=   0.2s
# [CV] criterion=gini, min_samples_leaf=19, min_samples_split=0.6808343088034366, n_estimators=131
# [CV]  criterion=gini, min_samples_leaf=19, min_samples_split=0.6808343088034366, n_estimators=131, total=   0.2s
# [CV] criterion=gini, min_samples_leaf=7, min_samples_split=0.5647251590372658, n_estimators=111
# [CV]  criterion=gini, min_samples_leaf=7, min_samples_split=0.5647251590372658, n_estimators=111, total=   0.1s
# [CV] criterion=gini, min_samples_leaf=7, min_samples_split=0.5647251590372658, n_estimators=111
# [CV]  criterion=gini, min_samples_leaf=7, min_samples_split=0.5647251590372658, n_estimators=111, total=   0.1s
# [CV] criterion=entropy, min_samples_leaf=12, min_samples_split=0.27210649344182436, n_estimators=129
# [CV]  criterion=entropy, min_samples_leaf=12, min_samples_split=0.27210649344182436, n_estimators=129, total=   0.2s
# [CV] criterion=entropy, min_samples_leaf=12, min_samples_split=0.27210649344182436, n_estimators=129
# [CV]  criterion=entropy, min_samples_leaf=12, min_samples_split=0.27210649344182436, n_estimators=129, total=   0.2s
# [CV] criterion=entropy, min_samples_leaf=9, min_samples_split=0.7947830690395926, n_estimators=115
# [CV]  criterion=entropy, min_samples_leaf=9, min_samples_split=0.7947830690395926, n_estimators=115, total=   0.1s
# [CV] criterion=entropy, min_samples_leaf=9, min_samples_split=0.7947830690395926, n_estimators=115
# [CV]  criterion=entropy, min_samples_leaf=9, min_samples_split=0.7947830690395926, n_estimators=115, total=   0.1s
# [CV] criterion=gini, min_samples_leaf=10, min_samples_split=0.5400440221615286, n_estimators=131
# [CV]  criterion=gini, min_samples_leaf=10, min_samples_split=0.5400440221615286, n_estimators=131, total=   0.2s
# [CV] criterion=gini, min_samples_leaf=10, min_samples_split=0.5400440221615286, n_estimators=131
# [CV]  criterion=gini, min_samples_leaf=10, min_samples_split=0.5400440221615286, n_estimators=131, total=   0.2s
# [CV] criterion=entropy, min_samples_leaf=9, min_samples_split=0.6919239338093545, n_estimators=109
# [CV]  criterion=entropy, min_samples_leaf=9, min_samples_split=0.6919239338093545, n_estimators=109, total=   0.1s
# [CV] criterion=entropy, min_samples_leaf=9, min_samples_split=0.6919239338093545, n_estimators=109
# [CV]  criterion=entropy, min_samples_leaf=9, min_samples_split=0.6919239338093545, n_estimators=109, total=   0.1s
# [CV] criterion=entropy, min_samples_leaf=1, min_samples_split=0.4335771083247697, n_estimators=70
# [CV]  criterion=entropy, min_samples_leaf=1, min_samples_split=0.4335771083247697, n_estimators=70, total=   0.1s
# [CV] criterion=entropy, min_samples_leaf=1, min_samples_split=0.4335771083247697, n_estimators=70
# [CV]  criterion=entropy, min_samples_leaf=1, min_samples_split=0.4335771083247697, n_estimators=70, total=   0.1s
# [CV] criterion=gini, min_samples_leaf=1, min_samples_split=0.524266831540189, n_estimators=74
# [CV]  criterion=gini, min_samples_leaf=1, min_samples_split=0.524266831540189, n_estimators=74, total=   0.1s
# [CV] criterion=gini, min_samples_leaf=1, min_samples_split=0.524266831540189, n_estimators=74
# [CV]  criterion=gini, min_samples_leaf=1, min_samples_split=0.524266831540189, n_estimators=74, total=   0.1s
# [CV] criterion=gini, min_samples_leaf=7, min_samples_split=0.9477336690026574, n_estimators=72
# [CV]  criterion=gini, min_samples_leaf=7, min_samples_split=0.9477336690026574, n_estimators=72, total=   0.1s
# [CV] criterion=gini, min_samples_leaf=7, min_samples_split=0.9477336690026574, n_estimators=72
# [CV]  criterion=gini, min_samples_leaf=7, min_samples_split=0.9477336690026574, n_estimators=72, total=   0.1s
# [CV] criterion=entropy, min_samples_leaf=4, min_samples_split=0.8929471346946736, n_estimators=134
# [CV]  criterion=entropy, min_samples_leaf=4, min_samples_split=0.8929471346946736, n_estimators=134, total=   0.2s
# [CV] criterion=entropy, min_samples_leaf=4, min_samples_split=0.8929471346946736, n_estimators=134
# [CV]  criterion=entropy, min_samples_leaf=4, min_samples_split=0.8929471346946736, n_estimators=134, total=   0.2s
# [CV] criterion=entropy, min_samples_leaf=10, min_samples_split=0.05272276029561551, n_estimators=118
# [CV]  criterion=entropy, min_samples_leaf=10, min_samples_split=0.05272276029561551, n_estimators=118, total=   0.2s
# [CV] criterion=entropy, min_samples_leaf=10, min_samples_split=0.05272276029561551, n_estimators=118
# [CV]  criterion=entropy, min_samples_leaf=10, min_samples_split=0.05272276029561551, n_estimators=118, total=   0.2s
# [CV] criterion=gini, min_samples_leaf=8, min_samples_split=0.7602461681372349, n_estimators=65
# [CV]  criterion=gini, min_samples_leaf=8, min_samples_split=0.7602461681372349, n_estimators=65, total=   0.1s
# [CV] criterion=gini, min_samples_leaf=8, min_samples_split=0.7602461681372349, n_estimators=65
# [CV]  criterion=gini, min_samples_leaf=8, min_samples_split=0.7602461681372349, n_estimators=65, total=   0.1s
# [CV] criterion=entropy, min_samples_leaf=2, min_samples_split=0.14493380303679182, n_estimators=142
# [CV]  criterion=entropy, min_samples_leaf=2, min_samples_split=0.14493380303679182, n_estimators=142, total=   0.2s
# [CV] criterion=entropy, min_samples_leaf=2, min_samples_split=0.14493380303679182, n_estimators=142
# [CV]  criterion=entropy, min_samples_leaf=2, min_samples_split=0.14493380303679182, n_estimators=142, total=   0.2s
# [CV] criterion=entropy, min_samples_leaf=15, min_samples_split=0.1243168817376552, n_estimators=134
# [CV]  criterion=entropy, min_samples_leaf=15, min_samples_split=0.1243168817376552, n_estimators=134, total=   0.2s
# [CV] criterion=entropy, min_samples_leaf=15, min_samples_split=0.1243168817376552, n_estimators=134
# [CV]  criterion=entropy, min_samples_leaf=15, min_samples_split=0.1243168817376552, n_estimators=134, total=   0.2s
# [CV] criterion=gini, min_samples_leaf=14, min_samples_split=0.5728421295845982, n_estimators=103
# [CV]  criterion=gini, min_samples_leaf=14, min_samples_split=0.5728421295845982, n_estimators=103, total=   0.1s
# [CV] criterion=gini, min_samples_leaf=14, min_samples_split=0.5728421295845982, n_estimators=103
# [CV]  criterion=gini, min_samples_leaf=14, min_samples_split=0.5728421295845982, n_estimators=103, total=   0.1s
# [CV] criterion=entropy, min_samples_leaf=13, min_samples_split=0.6379497066336408, n_estimators=93
# [CV]  criterion=entropy, min_samples_leaf=13, min_samples_split=0.6379497066336408, n_estimators=93, total=   0.1s
# [CV] criterion=entropy, min_samples_leaf=13, min_samples_split=0.6379497066336408, n_estimators=93
# [CV]  criterion=entropy, min_samples_leaf=13, min_samples_split=0.6379497066336408, n_estimators=93, total=   0.1s
# [CV] criterion=gini, min_samples_leaf=3, min_samples_split=0.5803926497277421, n_estimators=68
# [CV]  criterion=gini, min_samples_leaf=3, min_samples_split=0.5803926497277421, n_estimators=68, total=   0.1s
# [CV] criterion=gini, min_samples_leaf=3, min_samples_split=0.5803926497277421, n_estimators=68
# [CV]  criterion=gini, min_samples_leaf=3, min_samples_split=0.5803926497277421, n_estimators=68, total=   0.1s
# [CV] criterion=gini, min_samples_leaf=3, min_samples_split=0.6934435054226313, n_estimators=78
# [CV]  criterion=gini, min_samples_leaf=3, min_samples_split=0.6934435054226313, n_estimators=78, total=   0.1s
# [CV] criterion=gini, min_samples_leaf=3, min_samples_split=0.6934435054226313, n_estimators=78
# [CV]  criterion=gini, min_samples_leaf=3, min_samples_split=0.6934435054226313, n_estimators=78, total=   0.1s
# [CV] criterion=gini, min_samples_leaf=9, min_samples_split=0.15881535174624284, n_estimators=68
# [CV]  criterion=gini, min_samples_leaf=9, min_samples_split=0.15881535174624284, n_estimators=68, total=   0.1s
# [CV] criterion=gini, min_samples_leaf=9, min_samples_split=0.15881535174624284, n_estimators=68
# [CV]  criterion=gini, min_samples_leaf=9, min_samples_split=0.15881535174624284, n_estimators=68, total=   0.1s
# [CV] criterion=gini, min_samples_leaf=12, min_samples_split=0.06832659558468102, n_estimators=61
# [CV]  criterion=gini, min_samples_leaf=12, min_samples_split=0.06832659558468102, n_estimators=61, total=   0.1s
# [CV] criterion=gini, min_samples_leaf=12, min_samples_split=0.06832659558468102, n_estimators=61
# [CV]  criterion=gini, min_samples_leaf=12, min_samples_split=0.06832659558468102, n_estimators=61, total=   0.1s
# [CV] criterion=gini, min_samples_leaf=5, min_samples_split=0.44211965373656514, n_estimators=74
# [CV]  criterion=gini, min_samples_leaf=5, min_samples_split=0.44211965373656514, n_estimators=74, total=   0.1s
# [CV] criterion=gini, min_samples_leaf=5, min_samples_split=0.44211965373656514, n_estimators=74
# [CV]  criterion=gini, min_samples_leaf=5, min_samples_split=0.44211965373656514, n_estimators=74, total=   0.1s
# [CV] criterion=gini, min_samples_leaf=1, min_samples_split=0.48255933569409615, n_estimators=52
# [CV]  criterion=gini, min_samples_leaf=1, min_samples_split=0.48255933569409615, n_estimators=52, total=   0.1s
# [CV] criterion=gini, min_samples_leaf=1, min_samples_split=0.48255933569409615, n_estimators=52
# [CV]  criterion=gini, min_samples_leaf=1, min_samples_split=0.48255933569409615, n_estimators=52, total=   0.1s
# [CV] criterion=entropy, min_samples_leaf=10, min_samples_split=0.568980419100717, n_estimators=95
# [CV]  criterion=entropy, min_samples_leaf=10, min_samples_split=0.568980419100717, n_estimators=95, total=   0.1s
# [CV] criterion=entropy, min_samples_leaf=10, min_samples_split=0.568980419100717, n_estimators=95
# [CV]  criterion=entropy, min_samples_leaf=10, min_samples_split=0.568980419100717, n_estimators=95, total=   0.1s
# [CV] criterion=gini, min_samples_leaf=10, min_samples_split=0.7605972350664626, n_estimators=86
# [CV]  criterion=gini, min_samples_leaf=10, min_samples_split=0.7605972350664626, n_estimators=86, total=   0.1s
# [CV] criterion=gini, min_samples_leaf=10, min_samples_split=0.7605972350664626, n_estimators=86
# [CV]  criterion=gini, min_samples_leaf=10, min_samples_split=0.7605972350664626, n_estimators=86, total=   0.1s
# [CV] criterion=entropy, min_samples_leaf=5, min_samples_split=0.3022937267201027, n_estimators=99
# [CV]  criterion=entropy, min_samples_leaf=5, min_samples_split=0.3022937267201027, n_estimators=99, total=   0.2s
# [CV] criterion=entropy, min_samples_leaf=5, min_samples_split=0.3022937267201027, n_estimators=99
# [CV]  criterion=entropy, min_samples_leaf=5, min_samples_split=0.3022937267201027, n_estimators=99, total=   0.1s
# [CV] criterion=gini, min_samples_leaf=19, min_samples_split=0.3056768454383476, n_estimators=128
# [CV]  criterion=gini, min_samples_leaf=19, min_samples_split=0.3056768454383476, n_estimators=128, total=   0.2s
# [CV] criterion=gini, min_samples_leaf=19, min_samples_split=0.3056768454383476, n_estimators=128
# [CV]  criterion=gini, min_samples_leaf=19, min_samples_split=0.3056768454383476, n_estimators=128, total=   0.2s
# [CV] criterion=gini, min_samples_leaf=10, min_samples_split=0.5153474262319598, n_estimators=58
# [CV]  criterion=gini, min_samples_leaf=10, min_samples_split=0.5153474262319598, n_estimators=58, total=   0.1s
# [CV] criterion=gini, min_samples_leaf=10, min_samples_split=0.5153474262319598, n_estimators=58
# [CV]  criterion=gini, min_samples_leaf=10, min_samples_split=0.5153474262319598, n_estimators=58, total=   0.1s
# [CV] criterion=entropy, min_samples_leaf=2, min_samples_split=0.9781355435249156, n_estimators=142
# [CV]  criterion=entropy, min_samples_leaf=2, min_samples_split=0.9781355435249156, n_estimators=142, total=   0.2s
# [CV] criterion=entropy, min_samples_leaf=2, min_samples_split=0.9781355435249156, n_estimators=142
# [CV]  criterion=entropy, min_samples_leaf=2, min_samples_split=0.9781355435249156, n_estimators=142, total=   0.2s
# [CV] criterion=entropy, min_samples_leaf=14, min_samples_split=0.3646492023558007, n_estimators=139
# [CV]  criterion=entropy, min_samples_leaf=14, min_samples_split=0.3646492023558007, n_estimators=139, total=   0.2s
# [CV] criterion=entropy, min_samples_leaf=14, min_samples_split=0.3646492023558007, n_estimators=139
# [CV]  criterion=entropy, min_samples_leaf=14, min_samples_split=0.3646492023558007, n_estimators=139, total=   0.2s
# [CV] criterion=entropy, min_samples_leaf=7, min_samples_split=0.7422075297405593, n_estimators=77
# [CV]  criterion=entropy, min_samples_leaf=7, min_samples_split=0.7422075297405593, n_estimators=77, total=   0.1s
# [CV] criterion=entropy, min_samples_leaf=7, min_samples_split=0.7422075297405593, n_estimators=77
# [CV]  criterion=entropy, min_samples_leaf=7, min_samples_split=0.7422075297405593, n_estimators=77, total=   0.1s
# [CV] criterion=entropy, min_samples_leaf=18, min_samples_split=0.14637469621510746, n_estimators=95
# [CV]  criterion=entropy, min_samples_leaf=18, min_samples_split=0.14637469621510746, n_estimators=95, total=   0.2s
# [CV] criterion=entropy, min_samples_leaf=18, min_samples_split=0.14637469621510746, n_estimators=95
# [CV]  criterion=entropy, min_samples_leaf=18, min_samples_split=0.14637469621510746, n_estimators=95, total=   0.2s
# [CV] criterion=gini, min_samples_leaf=2, min_samples_split=0.5871966689947693, n_estimators=135
# ...
# [CV] criterion=entropy, min_samples_leaf=10, min_samples_split=0.40649089945806727, n_estimators=144
# [CV]  criterion=entropy, min_samples_leaf=10, min_samples_split=0.40649089945806727, n_estimators=144, total=   0.2s
# [CV] criterion=entropy, min_samples_leaf=10, min_samples_split=0.40649089945806727, n_estimators=144
# [CV]  criterion=entropy, min_samples_leaf=10, min_samples_split=0.40649089945806727, n_estimators=144, total=   0.2s
# [CV] criterion=entropy, min_samples_leaf=5, min_samples_split=0.5861099724774197, n_estimators=136
# [CV]  criterion=entropy, min_samples_leaf=5, min_samples_split=0.5861099724774197, n_estimators=136, total=   0.2s
# [CV] criterion=entropy, min_samples_leaf=5, min_samples_split=0.5861099724774197, n_estimators=136
# [CV]  criterion=entropy, min_samples_leaf=5, min_samples_split=0.5861099724774197, n_estimators=136, total=   0.2s
# [CV] criterion=entropy, min_samples_leaf=3, min_samples_split=0.9905850648429129, n_estimators=59
# [CV]  criterion=entropy, min_samples_leaf=3, min_samples_split=0.9905850648429129, n_estimators=59, total=   0.1s
# [CV] criterion=entropy, min_samples_leaf=3, min_samples_split=0.9905850648429129, n_estimators=59
# [CV]  criterion=entropy, min_samples_leaf=3, min_samples_split=0.9905850648429129, n_estimators=59, total=   0.1s
# [CV] criterion=gini, min_samples_leaf=11, min_samples_split=0.007699151673779436, n_estimators=123
# [CV]  criterion=gini, min_samples_leaf=11, min_samples_split=0.007699151673779436, n_estimators=123, total=   0.2s
# [CV] criterion=gini, min_samples_leaf=11, min_samples_split=0.007699151673779436, n_estimators=123
# [CV]  criterion=gini, min_samples_leaf=11, min_samples_split=0.007699151673779436, n_estimators=123, total=   0.2s
# [CV] criterion=entropy, min_samples_leaf=18, min_samples_split=0.567471866537498, n_estimators=115
# [CV]  criterion=entropy, min_samples_leaf=18, min_samples_split=0.567471866537498, n_estimators=115, total=   0.1s
# [CV] criterion=entropy, min_samples_leaf=18, min_samples_split=0.567471866537498, n_estimators=115
# [CV]  criterion=entropy, min_samples_leaf=18, min_samples_split=0.567471866537498, n_estimators=115, total=   0.1s
# [CV] criterion=gini, min_samples_leaf=14, min_samples_split=0.30318381968786867, n_estimators=63
# [CV]  criterion=gini, min_samples_leaf=14, min_samples_split=0.30318381968786867, n_estimators=63, total=   0.1s
# [CV] criterion=gini, min_samples_leaf=14, min_samples_split=0.30318381968786867, n_estimators=63
# [CV]  criterion=gini, min_samples_leaf=14, min_samples_split=0.30318381968786867, n_estimators=63, total=   0.1s
# [CV] criterion=entropy, min_samples_leaf=3, min_samples_split=0.11257548047108601, n_estimators=106
# [CV]  criterion=entropy, min_samples_leaf=3, min_samples_split=0.11257548047108601, n_estimators=106, total=   0.2s
# [CV] criterion=entropy, min_samples_leaf=3, min_samples_split=0.11257548047108601, n_estimators=106
# [CV]  criterion=entropy, min_samples_leaf=3, min_samples_split=0.11257548047108601, n_estimators=106, total=   0.2s
# [CV] criterion=gini, min_samples_leaf=7, min_samples_split=0.44523564613589806, n_estimators=71
# [CV]  criterion=gini, min_samples_leaf=7, min_samples_split=0.44523564613589806, n_estimators=71, total=   0.1s
# [CV] criterion=gini, min_samples_leaf=7, min_samples_split=0.44523564613589806, n_estimators=71
# [CV]  criterion=gini, min_samples_leaf=7, min_samples_split=0.44523564613589806, n_estimators=71, total=   0.1s
# [CV] criterion=entropy, min_samples_leaf=5, min_samples_split=0.9870371720026253, n_estimators=52
# [CV]  criterion=entropy, min_samples_leaf=5, min_samples_split=0.9870371720026253, n_estimators=52, total=   0.1s
# [CV] criterion=entropy, min_samples_leaf=5, min_samples_split=0.9870371720026253, n_estimators=52
# [CV]  criterion=entropy, min_samples_leaf=5, min_samples_split=0.9870371720026253, n_estimators=52, total=   0.1s
# [CV] criterion=entropy, min_samples_leaf=14, min_samples_split=0.5752414508639557, n_estimators=69
# [CV]  criterion=entropy, min_samples_leaf=14, min_samples_split=0.5752414508639557, n_estimators=69, total=   0.1s
# [CV] criterion=entropy, min_samples_leaf=14, min_samples_split=0.5752414508639557, n_estimators=69
# [CV]  criterion=entropy, min_samples_leaf=14, min_samples_split=0.5752414508639557, n_estimators=69, total=   0.1s
# [CV] criterion=entropy, min_samples_leaf=7, min_samples_split=0.1798092579237709, n_estimators=87
# [CV]  criterion=entropy, min_samples_leaf=7, min_samples_split=0.1798092579237709, n_estimators=87, total=   0.1s
# [CV] criterion=entropy, min_samples_leaf=7, min_samples_split=0.1798092579237709, n_estimators=87
# [CV]  criterion=entropy, min_samples_leaf=7, min_samples_split=0.1798092579237709, n_estimators=87, total=   0.1s
# [CV] criterion=gini, min_samples_leaf=14, min_samples_split=0.1791525734078605, n_estimators=90
# [CV]  criterion=gini, min_samples_leaf=14, min_samples_split=0.1791525734078605, n_estimators=90, total=   0.1s
# [CV] criterion=gini, min_samples_leaf=14, min_samples_split=0.1791525734078605, n_estimators=90
# [CV]  criterion=gini, min_samples_leaf=14, min_samples_split=0.1791525734078605, n_estimators=90, total=   0.1s
# [CV] criterion=entropy, min_samples_leaf=11, min_samples_split=0.6837458981385162, n_estimators=116
# [CV]  criterion=entropy, min_samples_leaf=11, min_samples_split=0.6837458981385162, n_estimators=116, total=   0.1s
# [CV] criterion=entropy, min_samples_leaf=11, min_samples_split=0.6837458981385162, n_estimators=116
# [CV]  criterion=entropy, min_samples_leaf=11, min_samples_split=0.6837458981385162, n_estimators=116, total=   0.1s
# [CV] criterion=entropy, min_samples_leaf=19, min_samples_split=0.8083312900003209, n_estimators=108
# [CV]  criterion=entropy, min_samples_leaf=19, min_samples_split=0.8083312900003209, n_estimators=108, total=   0.1s
# [CV] criterion=entropy, min_samples_leaf=19, min_samples_split=0.8083312900003209, n_estimators=108
# [CV]  criterion=entropy, min_samples_leaf=19, min_samples_split=0.8083312900003209, n_estimators=108, total=   0.1s
# [CV] criterion=gini, min_samples_leaf=4, min_samples_split=0.8431745149274358, n_estimators=108
# [CV]  criterion=gini, min_samples_leaf=4, min_samples_split=0.8431745149274358, n_estimators=108, total=   0.1s
# [CV] criterion=gini, min_samples_leaf=4, min_samples_split=0.8431745149274358, n_estimators=108
# [CV]  criterion=gini, min_samples_leaf=4, min_samples_split=0.8431745149274358, n_estimators=108, total=   0.1s
# [CV] criterion=entropy, min_samples_leaf=17, min_samples_split=0.8262029171685901, n_estimators=80
# [CV]  criterion=entropy, min_samples_leaf=17, min_samples_split=0.8262029171685901, n_estimators=80, total=   0.1s
# [CV] criterion=entropy, min_samples_leaf=17, min_samples_split=0.8262029171685901, n_estimators=80
# [CV]  criterion=entropy, min_samples_leaf=17, min_samples_split=0.8262029171685901, n_estimators=80, total=   0.1s
# [CV] criterion=entropy, min_samples_leaf=1, min_samples_split=0.12520699142139013, n_estimators=64
# [CV]  criterion=entropy, min_samples_leaf=1, min_samples_split=0.12520699142139013, n_estimators=64, total=   0.1s
# [CV] criterion=entropy, min_samples_leaf=1, min_samples_split=0.12520699142139013, n_estimators=64
# [CV]  criterion=entropy, min_samples_leaf=1, min_samples_split=0.12520699142139013, n_estimators=64, total=   0.1s
# [CV] criterion=entropy, min_samples_leaf=4, min_samples_split=0.7967674218916583, n_estimators=92
# [CV]  criterion=entropy, min_samples_leaf=4, min_samples_split=0.7967674218916583, n_estimators=92, total=   0.1s
# [CV] criterion=entropy, min_samples_leaf=4, min_samples_split=0.7967674218916583, n_estimators=92
# [CV]  criterion=entropy, min_samples_leaf=4, min_samples_split=0.7967674218916583, n_estimators=92, total=   0.1s
# [CV] criterion=gini, min_samples_leaf=3, min_samples_split=0.6190404367343123, n_estimators=59
# [CV]  criterion=gini, min_samples_leaf=3, min_samples_split=0.6190404367343123, n_estimators=59, total=   0.1s
# [CV] criterion=gini, min_samples_leaf=3, min_samples_split=0.6190404367343123, n_estimators=59
# [CV]  criterion=gini, min_samples_leaf=3, min_samples_split=0.6190404367343123, n_estimators=59, total=   0.1s
# [CV] criterion=gini, min_samples_leaf=15, min_samples_split=0.8517865644399247, n_estimators=64
# [CV]  criterion=gini, min_samples_leaf=15, min_samples_split=0.8517865644399247, n_estimators=64, total=   0.1s
# [CV] criterion=gini, min_samples_leaf=15, min_samples_split=0.8517865644399247, n_estimators=64
# [CV]  criterion=gini, min_samples_leaf=15, min_samples_split=0.8517865644399247, n_estimators=64, total=   0.1s
# [CV] criterion=entropy, min_samples_leaf=18, min_samples_split=0.6587377043528605, n_estimators=59
# [CV]  criterion=entropy, min_samples_leaf=18, min_samples_split=0.6587377043528605, n_estimators=59, total=   0.1s
# [CV] criterion=entropy, min_samples_leaf=18, min_samples_split=0.6587377043528605, n_estimators=59
# [CV]  criterion=entropy, min_samples_leaf=18, min_samples_split=0.6587377043528605, n_estimators=59, total=   0.1s
# [CV] criterion=entropy, min_samples_leaf=18, min_samples_split=0.9396169012441828, n_estimators=113
# [CV]  criterion=entropy, min_samples_leaf=18, min_samples_split=0.9396169012441828, n_estimators=113, total=   0.1s
# [CV] criterion=entropy, min_samples_leaf=18, min_samples_split=0.9396169012441828, n_estimators=113
# [CV]  criterion=entropy, min_samples_leaf=18, min_samples_split=0.9396169012441828, n_estimators=113, total=   0.1s
# [CV] criterion=entropy, min_samples_leaf=8, min_samples_split=0.9648932738133336, n_estimators=63
# [CV]  criterion=entropy, min_samples_leaf=8, min_samples_split=0.9648932738133336, n_estimators=63, total=   0.1s
# [CV] criterion=entropy, min_samples_leaf=8, min_samples_split=0.9648932738133336, n_estimators=63
# [CV]  criterion=entropy, min_samples_leaf=8, min_samples_split=0.9648932738133336, n_estimators=63, total=   0.1s
# [CV] criterion=gini, min_samples_leaf=14, min_samples_split=0.15574767630253727, n_estimators=111
# [CV]  criterion=gini, min_samples_leaf=14, min_samples_split=0.15574767630253727, n_estimators=111, total=   0.2s
# [CV] criterion=gini, min_samples_leaf=14, min_samples_split=0.15574767630253727, n_estimators=111
# [CV]  criterion=gini, min_samples_leaf=14, min_samples_split=0.15574767630253727, n_estimators=111, total=   0.2s
# [CV] criterion=gini, min_samples_leaf=19, min_samples_split=0.9911148979116879, n_estimators=70
# [CV]  criterion=gini, min_samples_leaf=19, min_samples_split=0.9911148979116879, n_estimators=70, total=   0.1s
# [CV] criterion=gini, min_samples_leaf=19, min_samples_split=0.9911148979116879, n_estimators=70
# [CV]  criterion=gini, min_samples_leaf=19, min_samples_split=0.9911148979116879, n_estimators=70, total=   0.1s
# [CV] criterion=gini, min_samples_leaf=15, min_samples_split=0.08945054941440467, n_estimators=52
# [CV]  criterion=gini, min_samples_leaf=15, min_samples_split=0.08945054941440467, n_estimators=52, total=   0.1s
# [CV] criterion=gini, min_samples_leaf=15, min_samples_split=0.08945054941440467, n_estimators=52
# [CV]  criterion=gini, min_samples_leaf=15, min_samples_split=0.08945054941440467, n_estimators=52, total=   0.1s
# [CV] criterion=entropy, min_samples_leaf=9, min_samples_split=0.9412474078047858, n_estimators=92
# [CV]  criterion=entropy, min_samples_leaf=9, min_samples_split=0.9412474078047858, n_estimators=92, total=   0.1s
# [CV] criterion=entropy, min_samples_leaf=9, min_samples_split=0.9412474078047858, n_estimators=92
# [CV]  criterion=entropy, min_samples_leaf=9, min_samples_split=0.9412474078047858, n_estimators=92, total=   0.1s
# [CV] criterion=gini, min_samples_leaf=9, min_samples_split=0.37438974848080087, n_estimators=107
# [CV]  criterion=gini, min_samples_leaf=9, min_samples_split=0.37438974848080087, n_estimators=107, total=   0.1s
# [CV] criterion=gini, min_samples_leaf=9, min_samples_split=0.37438974848080087, n_estimators=107
# [CV]  criterion=gini, min_samples_leaf=9, min_samples_split=0.37438974848080087, n_estimators=107, total=   0.1s
# [CV] criterion=gini, min_samples_leaf=19, min_samples_split=0.14482243772394354, n_estimators=137
# [CV]  criterion=gini, min_samples_leaf=19, min_samples_split=0.14482243772394354, n_estimators=137, total=   0.2s
# [CV] criterion=gini, min_samples_leaf=19, min_samples_split=0.14482243772394354, n_estimators=137
# [CV]  criterion=gini, min_samples_leaf=19, min_samples_split=0.14482243772394354, n_estimators=137, total=   0.2s
# [CV] criterion=gini, min_samples_leaf=13, min_samples_split=0.8681531715689944, n_estimators=76
# [CV]  criterion=gini, min_samples_leaf=13, min_samples_split=0.8681531715689944, n_estimators=76, total=   0.1s
# [CV] criterion=gini, min_samples_leaf=13, min_samples_split=0.8681531715689944, n_estimators=76
# [CV]  criterion=gini, min_samples_leaf=13, min_samples_split=0.8681531715689944, n_estimators=76, total=   0.1s
# [CV] criterion=gini, min_samples_leaf=3, min_samples_split=0.08224299931916401, n_estimators=99
# [CV]  criterion=gini, min_samples_leaf=3, min_samples_split=0.08224299931916401, n_estimators=99, total=   0.2s
# [CV] criterion=gini, min_samples_leaf=3, min_samples_split=0.08224299931916401, n_estimators=99
# [CV]  criterion=gini, min_samples_leaf=3, min_samples_split=0.08224299931916401, n_estimators=99, total=   0.2s
# [CV] criterion=gini, min_samples_leaf=7, min_samples_split=0.7337793888164438, n_estimators=81
# [CV]  criterion=gini, min_samples_leaf=7, min_samples_split=0.7337793888164438, n_estimators=81, total=   0.1s
# [CV] criterion=gini, min_samples_leaf=7, min_samples_split=0.7337793888164438, n_estimators=81
# [CV]  criterion=gini, min_samples_leaf=7, min_samples_split=0.7337793888164438, n_estimators=81, total=   0.1s
# [CV] criterion=gini, min_samples_leaf=1, min_samples_split=0.5660738072233006, n_estimators=78
# [CV]  criterion=gini, min_samples_leaf=1, min_samples_split=0.5660738072233006, n_estimators=78, total=   0.1s
# [CV] criterion=gini, min_samples_leaf=1, min_samples_split=0.5660738072233006, n_estimators=78
# [CV]  criterion=gini, min_samples_leaf=1, min_samples_split=0.5660738072233006, n_estimators=78, total=   0.1s
# [CV] criterion=gini, min_samples_leaf=6, min_samples_split=0.3495911012001238, n_estimators=60
# [CV]  criterion=gini, min_samples_leaf=6, min_samples_split=0.3495911012001238, n_estimators=60, total=   0.1s
# [CV] criterion=gini, min_samples_leaf=6, min_samples_split=0.3495911012001238, n_estimators=60
# [CV]  criterion=gini, min_samples_leaf=6, min_samples_split=0.3495911012001238, n_estimators=60, total=   0.1s
# [CV] criterion=gini, min_samples_leaf=6, min_samples_split=0.15190971670331954, n_estimators=137
# [CV]  criterion=gini, min_samples_leaf=6, min_samples_split=0.15190971670331954, n_estimators=137, total=   0.2s
# [CV] criterion=gini, min_samples_leaf=6, min_samples_split=0.15190971670331954, n_estimators=137
# [CV]  criterion=gini, min_samples_leaf=6, min_samples_split=0.15190971670331954, n_estimators=137, total=   0.2s
# [CV] criterion=entropy, min_samples_leaf=12, min_samples_split=0.5319029086790441, n_estimators=137
# [CV]  criterion=entropy, min_samples_leaf=12, min_samples_split=0.5319029086790441, n_estimators=137, total=   0.2s
# [CV] criterion=entropy, min_samples_leaf=12, min_samples_split=0.5319029086790441, n_estimators=137
# [CV]  criterion=entropy, min_samples_leaf=12, min_samples_split=0.5319029086790441, n_estimators=137, total=   0.2s
# [Parallel(n_jobs=1)]: Done 400 out of 400 | elapsed:   55.7s finished
# RandomizedSearchCV(cv=2, estimator=RandomForestClassifier(), n_iter=200,
#                    n_jobs=1,
#                    param_distributions={'criterion': ['gini', 'entropy'],
#                                         'min_samples_leaf': <scipy.stats._distn_infrastructure.rv_frozen object at 0x7f8b3916aaf0>,
#                                         'min_samples_split': <scipy.stats._distn_infrastructure.rv_frozen object at 0x7f8b3916a5e0>,
#                                         'n_estimators': <scipy.stats._distn_infrastructure.rv_frozen object at 0x7f8b09ac3fd0>},
#                    verbose=2)

# %%
best = search.best_params_
best["CV Score"] = search.best_score_
display(pd.DataFrame(best, index=[0]))
# Out:
#   criterion  min_samples_leaf  min_samples_split  n_estimators  CV Score
# 0   entropy                 6           0.002961           139     0.865

# %% [markdown]
# Задействуем все процессоры

# %%
model = RandomForestClassifier()

search = RandomizedSearchCV(
  estimator=model,
  param_distributions=space,
  n_iter=n_evals,
  n_jobs=-1,
  cv=2,
  verbose=2
)
search.fit(X_scaled, y)
# Out:
# Fitting 2 folds for each of 200 candidates, totalling 400 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:    2.9s
# [Parallel(n_jobs=-1)]: Done 154 tasks      | elapsed:   10.0s
# [Parallel(n_jobs=-1)]: Done 357 tasks      | elapsed:   23.0s
# [Parallel(n_jobs=-1)]: Done 400 out of 400 | elapsed:   26.0s finished
# RandomizedSearchCV(cv=2, estimator=RandomForestClassifier(), n_iter=200,
#                    n_jobs=-1,
#                    param_distributions={'criterion': ['gini', 'entropy'],
#                                         'min_samples_leaf': <scipy.stats._distn_infrastructure.rv_frozen object at 0x7f8b3916aaf0>,
#                                         'min_samples_split': <scipy.stats._distn_infrastructure.rv_frozen object at 0x7f8b3916a5e0>,
#                                         'n_estimators': <scipy.stats._distn_infrastructure.rv_frozen object at 0x7f8b09ac3fd0>},
#                    verbose=2)

# %%
best = search.best_params_
best["CV Score"] = search.best_score_
display(pd.DataFrame(best, index=[0]))
# Out:
#   criterion  min_samples_leaf  min_samples_split  n_estimators  CV Score
# 0   entropy                 7           0.007087           147     0.856

# %% [markdown]
# ## Подбор гиперпараметров на кластере

# %%
register_spark()

parallelism = 4
with parallel_backend("spark", n_jobs=parallelism):
    search = RandomizedSearchCV(
        estimator=model,
        param_distributions=space,
        n_iter=n_evals,
        cv=2,
        verbose=2
    )
    search.fit(X_scaled, y)
# Out:
# /home/ubuntu/.local/lib/python3.8/site-packages/joblibspark/backend.py:107: UserWarning: User-specified n_jobs (4) is greater than the max number of concurrent tasks (2) this cluster can run now.If dynamic allocation is enabled for the cluster, you might see more executors allocated.
#   warnings.warn(f"User-specified n_jobs ({n_jobs}) is greater than the max number of "
# /home/ubuntu/.local/lib/python3.8/site-packages/joblibspark/backend.py:107: UserWarning: User-specified n_jobs (4) is greater than the max number of concurrent tasks (2) this cluster can run now.If dynamic allocation is enabled for the cluster, you might see more executors allocated.
#   warnings.warn(f"User-specified n_jobs ({n_jobs}) is greater than the max number of "
# [Parallel(n_jobs=4)]: Using backend SparkDistributedBackend with 4 concurrent workers.
# Fitting 2 folds for each of 200 candidates, totalling 400 fits
# [Parallel(n_jobs=4)]: Done  33 tasks      | elapsed:    9.1s
# [Parallel(n_jobs=4)]: Done 154 tasks      | elapsed:   19.3s
# [Parallel(n_jobs=4)]: Done 357 tasks      | elapsed:   30.3s
# [Parallel(n_jobs=4)]: Done 400 out of 400 | elapsed:   32.6s finished

# %%
best = search.best_params_
best["CV Score"] = search.best_score_
display(pd.DataFrame(best, index=[0]))
# Out:
#   criterion  min_samples_leaf  min_samples_split  n_estimators  CV Score
# 0   entropy                 3           0.010258            72    0.8665

# %%
register_spark()

# %%
model = RandomForestClassifier()

# %%
parallelism = 16
with parallel_backend("spark", n_jobs=parallelism):
    search = RandomizedSearchCV(
        estimator=model,
        param_distributions=space,
        n_iter=n_evals,
        cv=2,
        verbose=2
    )
    search.fit(X_scaled, y)

# %%
spark.stop()
